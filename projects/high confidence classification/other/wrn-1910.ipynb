# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import StepLR
import scipy.stats as stats
import os

# Set a confidence threshold (e.g., 0.99 for 99% confidence)
CONFIDENCE_THRESHOLD = 0.99
PENALTY_WEIGHT = 10  # Weight for penalizing incorrect predictions after 50% accuracy
SAVE_PATH = './saved_models/'  # Directory to save model checkpoints
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# Focal Loss for handling imbalanced datasets
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, outputs, targets):
        BCE_loss = F.cross_entropy(outputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)  # Get the probability
        focal_loss = self.alpha * (1-pt)**self.gamma * BCE_loss
        return focal_loss.mean()

# Custom Loss Function with Focal Loss and Penalty for Wrong Predictions after 50% Accuracy
def custom_loss_function(outputs, targets, class_accuracy, current_accuracy):
    # Apply softmax to get probabilities
    probabilities = F.softmax(outputs, dim=1)
    
    # Get the max probability (confidence) and corresponding predicted class
    confidences, predicted_classes = torch.max(probabilities, dim=1)
    
    # Calculate the Focal Loss for class imbalance
    focal_loss = FocalLoss()(outputs, targets)
    
    # Heavily penalize wrong argmax predictions if training accuracy > 50%
    wrong_predictions = (predicted_classes != targets).float()
    if current_accuracy > 0.5:
        wrong_prediction_penalty = PENALTY_WEIGHT * wrong_predictions.sum()
    else:
        wrong_prediction_penalty = 0

    # Calculate the total loss
    total_loss = focal_loss + wrong_prediction_penalty
    return total_loss

# WideResNeXt Block
class WideResNeXtBlock(nn.Module):
    expansion = 2  # Expansion factor for WideResNeXt

    def __init__(self, in_planes, planes, stride=1, cardinality=32, widen_factor=2):
        super(WideResNeXtBlock, self).__init__()
        D = cardinality * widen_factor
        self.conv1 = nn.Conv2d(in_planes, D, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(D)
        self.conv2 = nn.Conv2d(D, D, kernel_size=3, stride=stride, padding=1, groups=cardinality, bias=False)
        self.bn2 = nn.BatchNorm2d(D)
        self.conv3 = nn.Conv2d(D, planes * WideResNeXtBlock.expansion, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes * WideResNeXtBlock.expansion)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes * WideResNeXtBlock.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * WideResNeXtBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * WideResNeXtBlock.expansion)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = torch.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# WideResNeXt Model
class WideResNeXt(nn.Module):
    def __init__(self, block, num_blocks, cardinality=32, widen_factor=2, num_classes=100):
        super(WideResNeXt, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)

        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1, cardinality=cardinality, widen_factor=widen_factor)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2, cardinality=cardinality, widen_factor=widen_factor)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2, cardinality=cardinality, widen_factor=widen_factor)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2, cardinality=cardinality, widen_factor=widen_factor)

        self.linear = nn.Linear(512 * WideResNeXtBlock.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride, cardinality, widen_factor):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride, cardinality, widen_factor))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = torch.nn.functional.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# WideResNeXt-101 Model Definition
def WideResNeXt101():
    return WideResNeXt(WideResNeXtBlock, [3, 4, 23, 3], cardinality=32, widen_factor=2)

# Training function with penalty for wrong predictions and tracking class-wise 100% accuracy
def train_with_penalty(epoch):
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    class_correct = {i: 0 for i in range(100)}  # Tracks correct predictions per class
    class_total = {i: 0 for i in range(100)}    # Tracks total predictions per class

    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        
        # Calculate the overall training accuracy before updating weights
        probabilities = F.softmax(outputs, dim=1)
        _, predicted_classes = torch.max(probabilities, dim=1)
        correct_predictions = predicted_classes.eq(targets).sum().item()
        total += targets.size(0)
        current_accuracy = correct_predictions / total
        
        # Calculate custom loss with penalties if training accuracy is above 50%
        loss = custom_loss_function(outputs, targets, class_accuracy, current_accuracy)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        correct += correct_predictions

        # Update per-class accuracy tracking
        for i in range(100):
            class_correct[i] += (predicted_classes == i).sum().item()
            class_total[i] += (targets == i).sum().item()

        if batch_idx % 100 == 0:
            print(f'Epoch {epoch}, Batch {batch_idx}, Loss: {train_loss / (batch_idx + 1):.3f}, Acc: {100.*correct/total:.3f}%')

    # Print if any class has been 100% correctly predicted
    for i in range(100):
        if class_total[i] > 0 and class_correct[i] == class_total[i]:
            print(f'Class {i} has been 100% correctly predicted.')

# Testing function to evaluate performance and save the best model
best_accuracy = 0.0  # Track the best accuracy

def test_with_penalty(epoch):
    global best_accuracy
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            
            loss = custom_loss_function(outputs, targets, class_accuracy, 0)  # Use 0 for test phase
            test_loss += loss.item()
            
            probabilities = F.softmax(outputs, dim=1)
            _, predicted_classes = torch.max(probabilities, dim=1)
            correct_predictions = predicted_classes.eq(targets).sum().item()
            correct += correct_predictions
            total += targets.size(0)

    test_accuracy = 100. * correct / total
    print(f'Test set: Average loss: {test_loss/len(testloader):.4f}, Accuracy: {correct}/{total} ({test_accuracy:.2f}%)')

    # Save the model at every 50th epoch
    if epoch % 50 == 0:
        save_path = os.path.join(SAVE_PATH, f'model_epoch_{epoch}.pth')
        torch.save(model.state_dict(), save_path)
        print(f"Model saved at epoch {epoch}.")

    # Save the best model based on test accuracy
    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        save_path = os.path.join(SAVE_PATH, 'best_model.pth')
        torch.save(model.state_dict(), save_path)
        print(f"New best model saved with accuracy: {test_accuracy:.2f}%")

# Load CIFAR-100 dataset
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

# Model, loss, optimizer, and scheduler
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = WideResNeXt101().to(device)

optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)
class_accuracy = {i: 1.0 for i in range(100)}

# Example Training Loop
for epoch in range(0, 100):
    train_with_penalty(epoch)
    test_with_penalty(epoch)
    scheduler.step()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169001437/169001437 [00:05<00:00, 29016271.62it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch 0, Batch 0, Loss: 4.653, Acc: 1.562%
# Epoch 0, Batch 100, Loss: 5.057, Acc: 1.145%
# Epoch 0, Batch 200, Loss: 4.755, Acc: 1.640%
# Epoch 0, Batch 300, Loss: 4.605, Acc: 2.121%
# Test set: Average loss: 4.0675, Accuracy: 495/10000 (4.95%)
# Model saved at epoch 0.
# New best model saved with accuracy: 4.95%
# Epoch 1, Batch 0, Loss: 3.992, Acc: 4.688%
# Epoch 1, Batch 100, Loss: 3.932, Acc: 6.536%
# Epoch 1, Batch 200, Loss: 3.839, Acc: 7.381%
# Epoch 1, Batch 300, Loss: 3.755, Acc: 8.194%
# Test set: Average loss: 3.3965, Accuracy: 1330/10000 (13.30%)
# New best model saved with accuracy: 13.30%
# Epoch 2, Batch 0, Loss: 3.289, Acc: 14.062%
# Epoch 2, Batch 100, Loss: 3.253, Acc: 14.349%
# Epoch 2, Batch 200, Loss: 3.177, Acc: 15.718%
# Epoch 2, Batch 300, Loss: 3.112, Acc: 16.928%
# Test set: Average loss: 3.2364, Accuracy: 1730/10000 (17.30%)
# New best model saved with accuracy: 17.30%
# Epoch 3, Batch 0, Loss: 2.709, Acc: 22.656%
# Epoch 3, Batch 100, Loss: 2.655, Acc: 24.474%
# Epoch 3, Batch 200, Loss: 2.597, Acc: 25.501%
# Epoch 3, Batch 300, Loss: 2.530, Acc: 26.697%
# Class 38 has been 100% correctly predicted.
# Test set: Average loss: 2.3966, Accuracy: 2872/10000 (28.72%)
# New best model saved with accuracy: 28.72%
# Epoch 4, Batch 0, Loss: 2.320, Acc: 34.375%
# Epoch 4, Batch 100, Loss: 2.196, Acc: 32.751%
# Epoch 4, Batch 200, Loss: 2.154, Acc: 33.524%
# Epoch 4, Batch 300, Loss: 2.119, Acc: 34.289%
# Test set: Average loss: 2.5201, Accuracy: 3457/10000 (34.57%)
# New best model saved with accuracy: 34.57%
# Epoch 5, Batch 0, Loss: 1.686, Acc: 45.312%
# Epoch 5, Batch 100, Loss: 1.865, Acc: 39.581%
# Epoch 5, Batch 200, Loss: 1.865, Acc: 39.552%
# Epoch 5, Batch 300, Loss: 1.845, Acc: 40.098%
# Class 18 has been 100% correctly predicted.
# Test set: Average loss: 2.1982, Accuracy: 3475/10000 (34.75%)
# New best model saved with accuracy: 34.75%
# Epoch 6, Batch 0, Loss: 1.438, Acc: 46.094%
# Epoch 6, Batch 100, Loss: 1.673, Acc: 43.526%
# Epoch 6, Batch 200, Loss: 1.687, Acc: 43.416%
# Epoch 6, Batch 300, Loss: 1.672, Acc: 43.755%
# Test set: Average loss: 1.7322, Accuracy: 4255/10000 (42.55%)
# New best model saved with accuracy: 42.55%
# Epoch 7, Batch 0, Loss: 1.752, Acc: 50.000%
# Epoch 7, Batch 100, Loss: 1.559, Acc: 46.836%
# Epoch 7, Batch 200, Loss: 1.563, Acc: 46.848%
# Epoch 7, Batch 300, Loss: 1.552, Acc: 47.002%
# Test set: Average loss: 1.7573, Accuracy: 4300/10000 (43.00%)
# New best model saved with accuracy: 43.00%
# Epoch 8, Batch 0, Loss: 621.285, Acc: 51.562%
# Epoch 8, Batch 100, Loss: 7.556, Acc: 49.884%
# Epoch 8, Batch 200, Loss: 4.525, Acc: 49.487%
# Epoch 8, Batch 300, Loss: 3.502, Acc: 49.452%
# Class 14 has been 100% correctly predicted.
# Class 90 has been 100% correctly predicted.
# Test set: Average loss: 1.7821, Accuracy: 4411/10000 (44.11%)
# New best model saved with accuracy: 44.11%
# Epoch 9, Batch 0, Loss: 1.452, Acc: 49.219%
# Epoch 9, Batch 100, Loss: 1.358, Acc: 51.300%
# Epoch 9, Batch 200, Loss: 1.353, Acc: 51.415%
# Epoch 9, Batch 300, Loss: 1.367, Acc: 51.230%
# Class 0 has been 100% correctly predicted.
# Test set: Average loss: 1.7816, Accuracy: 4277/10000 (42.77%)
# Epoch 10, Batch 0, Loss: 1.341, Acc: 46.094%
# Epoch 10, Batch 100, Loss: 1.306, Acc: 52.235%
# Epoch 10, Batch 200, Loss: 1.307, Acc: 52.437%
# Epoch 10, Batch 300, Loss: 1.314, Acc: 52.453%
# Class 31 has been 100% correctly predicted.
# Test set: Average loss: 1.5694, Accuracy: 4704/10000 (47.04%)
# New best model saved with accuracy: 47.04%
# Epoch 11, Batch 0, Loss: 611.420, Acc: 52.344%
# Epoch 11, Batch 100, Loss: 7.292, Acc: 54.107%
# Epoch 11, Batch 200, Loss: 4.285, Acc: 54.233%
# Epoch 11, Batch 300, Loss: 3.289, Acc: 53.984%
# Class 34 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 74 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 1.8618, Accuracy: 4309/10000 (43.09%)
# Epoch 12, Batch 0, Loss: 521.136, Acc: 59.375%
# Epoch 12, Batch 100, Loss: 6.347, Acc: 55.639%
# Epoch 12, Batch 200, Loss: 3.821, Acc: 54.684%
# Epoch 12, Batch 300, Loss: 2.959, Acc: 54.669%
# Class 86 has been 100% correctly predicted.
# Test set: Average loss: 1.6375, Accuracy: 4610/10000 (46.10%)
# Epoch 13, Batch 0, Loss: 511.114, Acc: 60.156%
# Epoch 13, Batch 100, Loss: 6.226, Acc: 56.791%
# Epoch 13, Batch 200, Loss: 3.722, Acc: 56.336%
# Epoch 13, Batch 300, Loss: 2.889, Acc: 56.016%
# Class 82 has been 100% correctly predicted.
# Test set: Average loss: 1.5226, Accuracy: 4848/10000 (48.48%)
# New best model saved with accuracy: 48.48%
# Epoch 14, Batch 0, Loss: 561.273, Acc: 56.250%
# Epoch 14, Batch 100, Loss: 6.675, Acc: 57.333%
# Epoch 14, Batch 200, Loss: 3.940, Acc: 56.794%
# Epoch 14, Batch 300, Loss: 3.027, Acc: 56.499%
# Class 37 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 60 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Test set: Average loss: 1.5137, Accuracy: 4867/10000 (48.67%)
# New best model saved with accuracy: 48.67%
# Epoch 15, Batch 0, Loss: 450.985, Acc: 64.844%
# Epoch 15, Batch 100, Loss: 5.603, Acc: 57.232%
# Epoch 15, Batch 200, Loss: 3.385, Acc: 56.845%
# Epoch 15, Batch 300, Loss: 2.649, Acc: 56.650%
# Test set: Average loss: 1.4545, Accuracy: 4997/10000 (49.97%)
# New best model saved with accuracy: 49.97%
# Epoch 16, Batch 0, Loss: 591.040, Acc: 53.906%
# Epoch 16, Batch 100, Loss: 6.955, Acc: 57.998%
# Epoch 16, Batch 200, Loss: 4.040, Acc: 58.337%
# Epoch 16, Batch 300, Loss: 3.082, Acc: 57.807%
# Class 8 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Test set: Average loss: 1.3807, Accuracy: 5216/10000 (52.16%)
# New best model saved with accuracy: 52.16%
# Epoch 17, Batch 0, Loss: 541.093, Acc: 57.812%
# Epoch 17, Batch 100, Loss: 6.417, Acc: 58.834%
# Epoch 17, Batch 200, Loss: 3.780, Acc: 58.151%
# Epoch 17, Batch 300, Loss: 2.895, Acc: 57.960%
# Class 0 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Test set: Average loss: 1.5683, Accuracy: 4766/10000 (47.66%)
# Epoch 18, Batch 0, Loss: 501.029, Acc: 60.938%
# Epoch 18, Batch 100, Loss: 6.024, Acc: 58.857%
# Epoch 18, Batch 200, Loss: 3.573, Acc: 58.862%
# Epoch 18, Batch 300, Loss: 2.754, Acc: 58.550%
# Class 30 has been 100% correctly predicted.
# Class 42 has been 100% correctly predicted.
# Class 44 has been 100% correctly predicted.
# Test set: Average loss: 1.6607, Accuracy: 4746/10000 (47.46%)
# Epoch 19, Batch 0, Loss: 510.998, Acc: 60.156%
# Epoch 19, Batch 100, Loss: 6.110, Acc: 59.824%
# Epoch 19, Batch 200, Loss: 3.596, Acc: 59.659%
# Epoch 19, Batch 300, Loss: 2.762, Acc: 59.253%
# Class 57 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Test set: Average loss: 1.5458, Accuracy: 4849/10000 (48.49%)
# Epoch 20, Batch 0, Loss: 441.039, Acc: 65.625%
# Epoch 20, Batch 100, Loss: 5.366, Acc: 60.992%
# Epoch 20, Batch 200, Loss: 3.241, Acc: 59.608%
# Epoch 20, Batch 300, Loss: 2.524, Acc: 59.222%
# Class 82 has been 100% correctly predicted.
# Test set: Average loss: 1.5079, Accuracy: 4954/10000 (49.54%)
# Epoch 21, Batch 0, Loss: 530.896, Acc: 58.594%
# Epoch 21, Batch 100, Loss: 6.288, Acc: 59.468%
# Epoch 21, Batch 200, Loss: 3.687, Acc: 59.359%
# Epoch 21, Batch 300, Loss: 2.825, Acc: 58.858%
# Test set: Average loss: 1.4159, Accuracy: 5229/10000 (52.29%)
# New best model saved with accuracy: 52.29%
# Epoch 22, Batch 0, Loss: 430.949, Acc: 66.406%
# Epoch 22, Batch 100, Loss: 5.245, Acc: 60.744%
# Epoch 22, Batch 200, Loss: 3.155, Acc: 60.183%
# Epoch 22, Batch 300, Loss: 2.452, Acc: 60.237%
# Class 42 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Test set: Average loss: 1.7195, Accuracy: 4563/10000 (45.63%)
# Epoch 23, Batch 0, Loss: 470.974, Acc: 63.281%
# Epoch 23, Batch 100, Loss: 5.661, Acc: 60.821%
# Epoch 23, Batch 200, Loss: 3.363, Acc: 60.525%
# Epoch 23, Batch 300, Loss: 2.592, Acc: 60.289%
# Class 60 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Class 99 has been 100% correctly predicted.
# Test set: Average loss: 1.3118, Accuracy: 5321/10000 (53.21%)
# New best model saved with accuracy: 53.21%
# Epoch 24, Batch 0, Loss: 510.870, Acc: 60.156%
# Epoch 24, Batch 100, Loss: 6.048, Acc: 61.641%
# Epoch 24, Batch 200, Loss: 3.549, Acc: 61.019%
# Epoch 24, Batch 300, Loss: 2.717, Acc: 60.655%
# Class 17 has been 100% correctly predicted.
# Class 24 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Test set: Average loss: 1.4598, Accuracy: 5050/10000 (50.50%)
# Epoch 25, Batch 0, Loss: 530.968, Acc: 58.594%
# Epoch 25, Batch 100, Loss: 6.237, Acc: 60.891%
# Epoch 25, Batch 200, Loss: 3.637, Acc: 60.627%
# Epoch 25, Batch 300, Loss: 2.769, Acc: 60.434%
# Class 36 has been 100% correctly predicted.
# Test set: Average loss: 1.3687, Accuracy: 5295/10000 (52.95%)
# Epoch 26, Batch 0, Loss: 520.968, Acc: 59.375%
# Epoch 26, Batch 100, Loss: 6.124, Acc: 61.440%
# Epoch 26, Batch 200, Loss: 3.578, Acc: 60.825%
# Epoch 26, Batch 300, Loss: 2.726, Acc: 60.810%
# Class 14 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Test set: Average loss: 1.5732, Accuracy: 4941/10000 (49.41%)
# Epoch 27, Batch 0, Loss: 480.968, Acc: 62.500%
# Epoch 27, Batch 100, Loss: 5.717, Acc: 61.734%
# Epoch 27, Batch 200, Loss: 3.369, Acc: 61.128%
# Epoch 27, Batch 300, Loss: 2.585, Acc: 61.013%
# Class 48 has been 100% correctly predicted.
# Test set: Average loss: 1.5686, Accuracy: 4765/10000 (47.65%)
# Epoch 28, Batch 0, Loss: 450.943, Acc: 64.844%
# Epoch 28, Batch 100, Loss: 5.415, Acc: 62.051%
# Epoch 28, Batch 200, Loss: 3.216, Acc: 61.641%
# Epoch 28, Batch 300, Loss: 2.481, Acc: 61.475%
# Class 1 has been 100% correctly predicted.
# Test set: Average loss: 1.3438, Accuracy: 5403/10000 (54.03%)
# New best model saved with accuracy: 54.03%
# Epoch 29, Batch 0, Loss: 420.737, Acc: 67.188%
# Epoch 29, Batch 100, Loss: 5.114, Acc: 61.997%
# Epoch 29, Batch 200, Loss: 3.053, Acc: 61.979%
# Epoch 29, Batch 300, Loss: 2.368, Acc: 61.752%
# Test set: Average loss: 1.4317, Accuracy: 5146/10000 (51.46%)
# Epoch 30, Batch 0, Loss: 551.188, Acc: 57.031%
# Epoch 30, Batch 100, Loss: 6.180, Acc: 70.019%
# Epoch 30, Batch 200, Loss: 3.414, Acc: 71.685%
# Epoch 30, Batch 300, Loss: 2.467, Acc: 72.822%
# Class 0 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Class 92 has been 100% correctly predicted.
# Test set: Average loss: 0.7297, Accuracy: 6979/10000 (69.79%)
# New best model saved with accuracy: 69.79%
# Epoch 31, Batch 0, Loss: 270.369, Acc: 78.906%
# Epoch 31, Batch 100, Loss: 3.183, Acc: 76.562%
# Epoch 31, Batch 200, Loss: 1.847, Acc: 76.807%
# Epoch 31, Batch 300, Loss: 1.391, Acc: 77.284%
# Class 57 has been 100% correctly predicted.
# Class 65 has been 100% correctly predicted.
# Test set: Average loss: 0.7125, Accuracy: 7109/10000 (71.09%)
# New best model saved with accuracy: 71.09%
# Epoch 32, Batch 0, Loss: 240.397, Acc: 81.250%
# Epoch 32, Batch 100, Loss: 2.822, Acc: 78.914%
# Epoch 32, Batch 200, Loss: 1.632, Acc: 79.377%
# Epoch 32, Batch 300, Loss: 1.237, Acc: 79.293%
# Class 18 has been 100% correctly predicted.
# Test set: Average loss: 0.6986, Accuracy: 7155/10000 (71.55%)
# New best model saved with accuracy: 71.55%
# Epoch 33, Batch 0, Loss: 220.378, Acc: 82.812%
# Epoch 33, Batch 100, Loss: 2.575, Acc: 81.103%
# Epoch 33, Batch 200, Loss: 1.495, Acc: 80.585%
# Epoch 33, Batch 300, Loss: 1.138, Acc: 80.300%
# Class 3 has been 100% correctly predicted.
# Class 6 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 37 has been 100% correctly predicted.
# Test set: Average loss: 0.7065, Accuracy: 7118/10000 (71.18%)
# Epoch 34, Batch 0, Loss: 240.308, Acc: 81.250%
# Epoch 34, Batch 100, Loss: 2.736, Acc: 81.915%
# Epoch 34, Batch 200, Loss: 1.563, Acc: 81.297%
# Epoch 34, Batch 300, Loss: 1.171, Acc: 81.245%
# Class 2 has been 100% correctly predicted.
# Class 3 has been 100% correctly predicted.
# Class 44 has been 100% correctly predicted.
# Test set: Average loss: 0.7106, Accuracy: 7106/10000 (71.06%)
# Epoch 35, Batch 0, Loss: 270.507, Acc: 78.906%
# Epoch 35, Batch 100, Loss: 3.016, Acc: 82.232%
# Epoch 35, Batch 200, Loss: 1.694, Acc: 82.023%
# Epoch 35, Batch 300, Loss: 1.247, Acc: 82.091%
# Class 0 has been 100% correctly predicted.
# Class 7 has been 100% correctly predicted.
# Class 9 has been 100% correctly predicted.
# Class 33 has been 100% correctly predicted.
# Class 62 has been 100% correctly predicted.
# Test set: Average loss: 0.7064, Accuracy: 7145/10000 (71.45%)
# Epoch 36, Batch 0, Loss: 190.373, Acc: 85.156%
# Epoch 36, Batch 100, Loss: 2.197, Acc: 83.222%
# Epoch 36, Batch 200, Loss: 1.267, Acc: 82.960%
# Epoch 36, Batch 300, Loss: 0.954, Acc: 82.945%
# Class 39 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 62 has been 100% correctly predicted.
# Class 86 has been 100% correctly predicted.
# Test set: Average loss: 0.7274, Accuracy: 7115/10000 (71.15%)
# Epoch 37, Batch 0, Loss: 190.275, Acc: 85.156%
# Epoch 37, Batch 100, Loss: 2.178, Acc: 83.779%
# Epoch 37, Batch 200, Loss: 1.244, Acc: 83.897%
# Epoch 37, Batch 300, Loss: 0.932, Acc: 83.801%
# Class 8 has been 100% correctly predicted.
# Class 37 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Test set: Average loss: 0.7140, Accuracy: 7161/10000 (71.61%)
# New best model saved with accuracy: 71.61%
# Epoch 38, Batch 0, Loss: 80.167, Acc: 93.750%
# Epoch 38, Batch 100, Loss: 1.059, Acc: 85.520%
# Epoch 38, Batch 200, Loss: 0.675, Acc: 85.125%
# Epoch 38, Batch 300, Loss: 0.548, Acc: 84.658%
# Class 6 has been 100% correctly predicted.
# Class 7 has been 100% correctly predicted.
# Class 14 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Test set: Average loss: 0.7293, Accuracy: 7122/10000 (71.22%)
# Epoch 39, Batch 0, Loss: 220.304, Acc: 82.812%
# Epoch 39, Batch 100, Loss: 2.431, Acc: 85.558%
# Epoch 39, Batch 200, Loss: 1.357, Acc: 85.292%
# Epoch 39, Batch 300, Loss: 1.001, Acc: 85.011%
# Class 20 has been 100% correctly predicted.
# Class 53 has been 100% correctly predicted.
# Test set: Average loss: 0.7734, Accuracy: 7044/10000 (70.44%)
# Epoch 40, Batch 0, Loss: 210.333, Acc: 83.594%
# Epoch 40, Batch 100, Loss: 2.317, Acc: 86.239%
# Epoch 40, Batch 200, Loss: 1.294, Acc: 85.821%
# Epoch 40, Batch 300, Loss: 0.956, Acc: 85.475%
# Class 53 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 97 has been 100% correctly predicted.
# Test set: Average loss: 0.7432, Accuracy: 7100/10000 (71.00%)
# Epoch 41, Batch 0, Loss: 200.309, Acc: 84.375%
# Epoch 41, Batch 100, Loss: 2.207, Acc: 87.276%
# Epoch 41, Batch 200, Loss: 1.229, Acc: 86.680%
# Epoch 41, Batch 300, Loss: 0.903, Acc: 86.335%
# Class 17 has been 100% correctly predicted.
# Class 70 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 85 has been 100% correctly predicted.
# Test set: Average loss: 0.7543, Accuracy: 7089/10000 (70.89%)
# Epoch 42, Batch 0, Loss: 140.201, Acc: 89.062%
# Epoch 42, Batch 100, Loss: 1.604, Acc: 87.469%
# Epoch 42, Batch 200, Loss: 0.922, Acc: 86.995%
# Epoch 42, Batch 300, Loss: 0.696, Acc: 86.659%
# Class 23 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 85 has been 100% correctly predicted.
# Test set: Average loss: 0.7663, Accuracy: 7070/10000 (70.70%)
# Epoch 43, Batch 0, Loss: 160.156, Acc: 87.500%
# Epoch 43, Batch 100, Loss: 1.781, Acc: 87.809%
# Epoch 43, Batch 200, Loss: 1.004, Acc: 87.391%
# Epoch 43, Batch 300, Loss: 0.747, Acc: 87.131%
# Class 4 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 25 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 97 has been 100% correctly predicted.
# Test set: Average loss: 0.7783, Accuracy: 7039/10000 (70.39%)
# Epoch 44, Batch 0, Loss: 140.152, Acc: 89.062%
# Epoch 44, Batch 100, Loss: 1.578, Acc: 88.127%
# Epoch 44, Batch 200, Loss: 0.899, Acc: 87.687%
# Epoch 44, Batch 300, Loss: 0.673, Acc: 87.466%
# Class 27 has been 100% correctly predicted.
# Class 35 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 55 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 86 has been 100% correctly predicted.
# Class 99 has been 100% correctly predicted.
# Test set: Average loss: 0.8046, Accuracy: 6999/10000 (69.99%)
# Epoch 45, Batch 0, Loss: 120.161, Acc: 90.625%
# Epoch 45, Batch 100, Loss: 1.377, Acc: 87.933%
# Epoch 45, Batch 200, Loss: 0.792, Acc: 87.764%
# Epoch 45, Batch 300, Loss: 0.603, Acc: 87.381%
# Class 63 has been 100% correctly predicted.
# Class 70 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Class 99 has been 100% correctly predicted.
# Test set: Average loss: 0.7855, Accuracy: 7015/10000 (70.15%)
# Epoch 46, Batch 0, Loss: 170.227, Acc: 86.719%
# Epoch 46, Batch 100, Loss: 1.870, Acc: 88.297%
# Epoch 46, Batch 200, Loss: 1.042, Acc: 87.865%
# Epoch 46, Batch 300, Loss: 0.765, Acc: 87.695%
# Class 2 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 62 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Class 99 has been 100% correctly predicted.
# Test set: Average loss: 0.8332, Accuracy: 6969/10000 (69.69%)
# Epoch 47, Batch 0, Loss: 150.161, Acc: 88.281%
# Epoch 47, Batch 100, Loss: 1.667, Acc: 88.645%
# Epoch 47, Batch 200, Loss: 0.935, Acc: 88.297%
# Epoch 47, Batch 300, Loss: 0.693, Acc: 87.858%
# Class 4 has been 100% correctly predicted.
# Class 8 has been 100% correctly predicted.
# Class 32 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 67 has been 100% correctly predicted.
# Class 80 has been 100% correctly predicted.
# Class 87 has been 100% correctly predicted.
# Test set: Average loss: 0.8505, Accuracy: 6950/10000 (69.50%)
# Epoch 48, Batch 0, Loss: 120.209, Acc: 90.625%
# Epoch 48, Batch 100, Loss: 1.367, Acc: 88.800%
# Epoch 48, Batch 200, Loss: 0.784, Acc: 88.596%
# Epoch 48, Batch 300, Loss: 0.589, Acc: 88.294%
# Class 4 has been 100% correctly predicted.
# Class 23 has been 100% correctly predicted.
# Class 25 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 87 has been 100% correctly predicted.
# Test set: Average loss: 0.8285, Accuracy: 6988/10000 (69.88%)
# Epoch 49, Batch 0, Loss: 160.211, Acc: 87.500%
# Epoch 49, Batch 100, Loss: 1.753, Acc: 89.813%
# Epoch 49, Batch 200, Loss: 0.971, Acc: 89.241%
# Epoch 49, Batch 300, Loss: 0.714, Acc: 88.774%
# Class 20 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 67 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Test set: Average loss: 0.8270, Accuracy: 7049/10000 (70.49%)
# Epoch 50, Batch 0, Loss: 70.124, Acc: 94.531%
# Epoch 50, Batch 100, Loss: 0.854, Acc: 89.511%
# Epoch 50, Batch 200, Loss: 0.516, Acc: 89.113%
# Epoch 50, Batch 300, Loss: 0.412, Acc: 88.502%
# Class 0 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 72 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 93 has been 100% correctly predicted.
# Test set: Average loss: 0.8527, Accuracy: 6953/10000 (69.53%)
# Model saved at epoch 50.
# Epoch 51, Batch 0, Loss: 60.098, Acc: 95.312%
# Epoch 51, Batch 100, Loss: 0.761, Acc: 89.202%
# Epoch 51, Batch 200, Loss: 0.470, Acc: 89.062%
# Epoch 51, Batch 300, Loss: 0.376, Acc: 88.842%
# Class 0 has been 100% correctly predicted.
# Class 18 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Test set: Average loss: 0.8724, Accuracy: 6884/10000 (68.84%)
# Epoch 52, Batch 0, Loss: 80.111, Acc: 93.750%
# Epoch 52, Batch 100, Loss: 0.963, Acc: 89.202%
# Epoch 52, Batch 200, Loss: 0.566, Acc: 89.164%
# Epoch 52, Batch 300, Loss: 0.439, Acc: 88.977%
# Class 25 has been 100% correctly predicted.
# Class 33 has been 100% correctly predicted.
# Class 86 has been 100% correctly predicted.
# Test set: Average loss: 0.8280, Accuracy: 6940/10000 (69.40%)
# Epoch 53, Batch 0, Loss: 150.182, Acc: 88.281%
# Epoch 53, Batch 100, Loss: 1.643, Acc: 89.921%
# Epoch 53, Batch 200, Loss: 0.910, Acc: 89.490%
# Epoch 53, Batch 300, Loss: 0.670, Acc: 88.977%
# Class 12 has been 100% correctly predicted.
# Class 18 has been 100% correctly predicted.
# Class 24 has been 100% correctly predicted.
# Class 25 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.8549, Accuracy: 6902/10000 (69.02%)
# Epoch 54, Batch 0, Loss: 90.109, Acc: 92.969%
# Epoch 54, Batch 100, Loss: 1.055, Acc: 89.542%
# Epoch 54, Batch 200, Loss: 0.617, Acc: 89.152%
# Epoch 54, Batch 300, Loss: 0.472, Acc: 88.938%
# Class 1 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Test set: Average loss: 0.8616, Accuracy: 6941/10000 (69.41%)
# Epoch 55, Batch 0, Loss: 120.175, Acc: 90.625%
# Epoch 55, Batch 100, Loss: 1.350, Acc: 89.712%
# Epoch 55, Batch 200, Loss: 0.760, Acc: 89.607%
# Epoch 55, Batch 300, Loss: 0.567, Acc: 89.296%
# Class 35 has been 100% correctly predicted.
# Class 54 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Test set: Average loss: 0.8591, Accuracy: 6951/10000 (69.51%)
# Epoch 56, Batch 0, Loss: 50.117, Acc: 96.094%
# Epoch 56, Batch 100, Loss: 0.659, Acc: 89.844%
# Epoch 56, Batch 200, Loss: 0.418, Acc: 89.467%
# Epoch 56, Batch 300, Loss: 0.339, Acc: 89.197%
# Class 29 has been 100% correctly predicted.
# Class 33 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Class 92 has been 100% correctly predicted.
# Test set: Average loss: 0.8899, Accuracy: 6876/10000 (68.76%)
# Epoch 57, Batch 0, Loss: 90.158, Acc: 92.969%
# Epoch 57, Batch 100, Loss: 1.051, Acc: 89.790%
# Epoch 57, Batch 200, Loss: 0.614, Acc: 89.537%
# Epoch 57, Batch 300, Loss: 0.473, Acc: 89.094%
# Class 18 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 23 has been 100% correctly predicted.
# Class 30 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Class 93 has been 100% correctly predicted.
# Test set: Average loss: 0.8662, Accuracy: 6927/10000 (69.27%)
# Epoch 58, Batch 0, Loss: 100.124, Acc: 92.188%
# Epoch 58, Batch 100, Loss: 1.138, Acc: 90.625%
# Epoch 58, Batch 200, Loss: 0.650, Acc: 90.205%
# Epoch 58, Batch 300, Loss: 0.495, Acc: 89.525%
# Class 8 has been 100% correctly predicted.
# Class 30 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 38 has been 100% correctly predicted.
# Test set: Average loss: 0.8797, Accuracy: 6959/10000 (69.59%)
# Epoch 59, Batch 0, Loss: 50.131, Acc: 96.094%
# Epoch 59, Batch 100, Loss: 0.647, Acc: 90.385%
# Epoch 59, Batch 200, Loss: 0.408, Acc: 89.883%
# Epoch 59, Batch 300, Loss: 0.333, Acc: 89.579%
# Class 4 has been 100% correctly predicted.
# Class 20 has been 100% correctly predicted.
# Class 36 has been 100% correctly predicted.
# Class 43 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 78 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.8632, Accuracy: 6937/10000 (69.37%)
# Epoch 60, Batch 0, Loss: 180.231, Acc: 85.938%
# Epoch 60, Batch 100, Loss: 1.903, Acc: 92.079%
# Epoch 60, Batch 200, Loss: 1.003, Acc: 92.930%
# Epoch 60, Batch 300, Loss: 0.699, Acc: 93.423%
# Class 58 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Test set: Average loss: 0.7438, Accuracy: 7282/10000 (72.82%)
# New best model saved with accuracy: 72.82%
# Epoch 61, Batch 0, Loss: 60.067, Acc: 95.312%
# Epoch 61, Batch 100, Loss: 0.665, Acc: 95.173%
# Epoch 61, Batch 200, Loss: 0.369, Acc: 95.243%
# Epoch 61, Batch 300, Loss: 0.268, Acc: 95.398%
# Class 14 has been 100% correctly predicted.
# Class 23 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 55 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Test set: Average loss: 0.7384, Accuracy: 7316/10000 (73.16%)
# New best model saved with accuracy: 73.16%
# Epoch 62, Batch 0, Loss: 40.055, Acc: 96.875%
# Epoch 62, Batch 100, Loss: 0.456, Acc: 95.962%
# Epoch 62, Batch 200, Loss: 0.260, Acc: 95.876%
# Epoch 62, Batch 300, Loss: 0.191, Acc: 96.003%
# Class 4 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 93 has been 100% correctly predicted.
# Test set: Average loss: 0.7504, Accuracy: 7292/10000 (72.92%)
# Epoch 63, Batch 0, Loss: 70.069, Acc: 94.531%
# Epoch 63, Batch 100, Loss: 0.745, Acc: 96.364%
# Epoch 63, Batch 200, Loss: 0.401, Acc: 96.432%
# Epoch 63, Batch 300, Loss: 0.286, Acc: 96.361%
# Class 31 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 50 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 62 has been 100% correctly predicted.
# Class 64 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Class 86 has been 100% correctly predicted.
# Test set: Average loss: 0.7470, Accuracy: 7315/10000 (73.15%)
# Epoch 64, Batch 0, Loss: 40.068, Acc: 96.875%
# Epoch 64, Batch 100, Loss: 0.445, Acc: 96.782%
# Epoch 64, Batch 200, Loss: 0.248, Acc: 96.844%
# Epoch 64, Batch 300, Loss: 0.181, Acc: 96.815%
# Class 0 has been 100% correctly predicted.
# Class 1 has been 100% correctly predicted.
# Class 2 has been 100% correctly predicted.
# Class 22 has been 100% correctly predicted.
# Class 23 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Test set: Average loss: 0.7489, Accuracy: 7312/10000 (73.12%)
# Epoch 65, Batch 0, Loss: 70.059, Acc: 94.531%
# Epoch 65, Batch 100, Loss: 0.738, Acc: 96.883%
# Epoch 65, Batch 200, Loss: 0.393, Acc: 96.949%
# Epoch 65, Batch 300, Loss: 0.277, Acc: 96.987%
# Class 3 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 46 has been 100% correctly predicted.
# Class 53 has been 100% correctly predicted.
# Class 55 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 80 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Class 97 has been 100% correctly predicted.
# Class 99 has been 100% correctly predicted.
# Test set: Average loss: 0.7513, Accuracy: 7314/10000 (73.14%)
# Epoch 66, Batch 0, Loss: 40.057, Acc: 96.875%
# Epoch 66, Batch 100, Loss: 0.439, Acc: 97.099%
# Epoch 66, Batch 200, Loss: 0.241, Acc: 97.201%
# Epoch 66, Batch 300, Loss: 0.175, Acc: 97.218%
# Class 3 has been 100% correctly predicted.
# Class 6 has been 100% correctly predicted.
# Class 10 has been 100% correctly predicted.
# Class 16 has been 100% correctly predicted.
# Class 20 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 40 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 43 has been 100% correctly predicted.
# Class 46 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 54 has been 100% correctly predicted.
# Class 74 has been 100% correctly predicted.
# Class 93 has been 100% correctly predicted.
# Test set: Average loss: 0.7558, Accuracy: 7317/10000 (73.17%)
# New best model saved with accuracy: 73.17%
# Epoch 67, Batch 0, Loss: 40.027, Acc: 96.875%
# Epoch 67, Batch 100, Loss: 0.435, Acc: 97.370%
# Epoch 67, Batch 200, Loss: 0.239, Acc: 97.295%
# Epoch 67, Batch 300, Loss: 0.173, Acc: 97.337%
# Class 1 has been 100% correctly predicted.
# Class 14 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 53 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Test set: Average loss: 0.7559, Accuracy: 7341/10000 (73.41%)
# New best model saved with accuracy: 73.41%
# Epoch 68, Batch 0, Loss: 40.044, Acc: 96.875%
# Epoch 68, Batch 100, Loss: 0.435, Acc: 97.455%
# Epoch 68, Batch 200, Loss: 0.237, Acc: 97.442%
# Epoch 68, Batch 300, Loss: 0.172, Acc: 97.402%
# Class 12 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 53 has been 100% correctly predicted.
# Class 54 has been 100% correctly predicted.
# Class 74 has been 100% correctly predicted.
# Class 85 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Test set: Average loss: 0.7580, Accuracy: 7316/10000 (73.16%)
# Epoch 69, Batch 0, Loss: 30.034, Acc: 97.656%
# Epoch 69, Batch 100, Loss: 0.334, Acc: 97.378%
# Epoch 69, Batch 200, Loss: 0.187, Acc: 97.446%
# Epoch 69, Batch 300, Loss: 0.137, Acc: 97.495%
# Class 23 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 32 has been 100% correctly predicted.
# Class 33 has been 100% correctly predicted.
# Class 36 has been 100% correctly predicted.
# Class 43 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 64 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Test set: Average loss: 0.7613, Accuracy: 7322/10000 (73.22%)
# Epoch 70, Batch 0, Loss: 20.041, Acc: 98.438%
# Epoch 70, Batch 100, Loss: 0.234, Acc: 97.478%
# Epoch 70, Batch 200, Loss: 0.135, Acc: 97.672%
# Epoch 70, Batch 300, Loss: 0.101, Acc: 97.700%
# Class 6 has been 100% correctly predicted.
# Class 12 has been 100% correctly predicted.
# Class 16 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 28 has been 100% correctly predicted.
# Class 40 has been 100% correctly predicted.
# Class 46 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 58 has been 100% correctly predicted.
# Class 67 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Test set: Average loss: 0.7640, Accuracy: 7336/10000 (73.36%)
# Epoch 71, Batch 0, Loss: 20.017, Acc: 98.438%
# Epoch 71, Batch 100, Loss: 0.233, Acc: 97.734%
# Epoch 71, Batch 200, Loss: 0.134, Acc: 97.804%
# Epoch 71, Batch 300, Loss: 0.101, Acc: 97.770%
# Class 5 has been 100% correctly predicted.
# Class 15 has been 100% correctly predicted.
# Class 18 has been 100% correctly predicted.
# Class 25 has been 100% correctly predicted.
# Class 53 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 58 has been 100% correctly predicted.
# Class 65 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Test set: Average loss: 0.7569, Accuracy: 7342/10000 (73.42%)
# New best model saved with accuracy: 73.42%
# Epoch 72, Batch 0, Loss: 10.028, Acc: 99.219%
# Epoch 72, Batch 100, Loss: 0.130, Acc: 97.904%
# Epoch 72, Batch 200, Loss: 0.081, Acc: 97.932%
# Epoch 72, Batch 300, Loss: 0.065, Acc: 97.890%
# Class 1 has been 100% correctly predicted.
# Class 6 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 22 has been 100% correctly predicted.
# Class 28 has been 100% correctly predicted.
# Class 30 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 72 has been 100% correctly predicted.
# Class 74 has been 100% correctly predicted.
# Class 99 has been 100% correctly predicted.
# Test set: Average loss: 0.7642, Accuracy: 7332/10000 (73.32%)
# Epoch 73, Batch 0, Loss: 60.063, Acc: 95.312%
# Epoch 73, Batch 100, Loss: 0.626, Acc: 97.826%
# Epoch 73, Batch 200, Loss: 0.330, Acc: 97.854%
# Epoch 73, Batch 300, Loss: 0.231, Acc: 97.835%
# Class 6 has been 100% correctly predicted.
# Class 7 has been 100% correctly predicted.
# Class 8 has been 100% correctly predicted.
# Class 22 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 45 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Test set: Average loss: 0.7642, Accuracy: 7346/10000 (73.46%)
# New best model saved with accuracy: 73.46%
# Epoch 74, Batch 0, Loss: 0.016, Acc: 100.000%
# Epoch 74, Batch 100, Loss: 0.030, Acc: 98.004%
# Epoch 74, Batch 200, Loss: 0.031, Acc: 97.987%
# Epoch 74, Batch 300, Loss: 0.031, Acc: 97.952%
# Class 2 has been 100% correctly predicted.
# Class 5 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 43 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 60 has been 100% correctly predicted.
# Class 64 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Test set: Average loss: 0.7672, Accuracy: 7342/10000 (73.42%)
# Epoch 75, Batch 0, Loss: 30.027, Acc: 97.656%
# Epoch 75, Batch 100, Loss: 0.325, Acc: 98.213%
# Epoch 75, Batch 200, Loss: 0.178, Acc: 98.111%
# Epoch 75, Batch 300, Loss: 0.128, Acc: 98.087%
# Class 0 has been 100% correctly predicted.
# Class 3 has been 100% correctly predicted.
# Class 14 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 22 has been 100% correctly predicted.
# Class 33 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 54 has been 100% correctly predicted.
# Class 58 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 87 has been 100% correctly predicted.
# Test set: Average loss: 0.7677, Accuracy: 7346/10000 (73.46%)
# Epoch 76, Batch 0, Loss: 50.028, Acc: 96.094%
# Epoch 76, Batch 100, Loss: 0.523, Acc: 98.229%
# Epoch 76, Batch 200, Loss: 0.276, Acc: 98.266%
# Epoch 76, Batch 300, Loss: 0.194, Acc: 98.230%
# Class 1 has been 100% correctly predicted.
# Class 4 has been 100% correctly predicted.
# Class 6 has been 100% correctly predicted.
# Class 8 has been 100% correctly predicted.
# Class 12 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 53 has been 100% correctly predicted.
# Class 62 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.7704, Accuracy: 7337/10000 (73.37%)
# Epoch 77, Batch 0, Loss: 40.041, Acc: 96.875%
# Epoch 77, Batch 100, Loss: 0.422, Acc: 98.577%
# Epoch 77, Batch 200, Loss: 0.224, Acc: 98.515%
# Epoch 77, Batch 300, Loss: 0.159, Acc: 98.396%
# Class 4 has been 100% correctly predicted.
# Class 9 has been 100% correctly predicted.
# Class 14 has been 100% correctly predicted.
# Class 18 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 42 has been 100% correctly predicted.
# Class 46 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 59 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 70 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Test set: Average loss: 0.7681, Accuracy: 7345/10000 (73.45%)
# Epoch 78, Batch 0, Loss: 20.030, Acc: 98.438%
# Epoch 78, Batch 100, Loss: 0.223, Acc: 98.484%
# Epoch 78, Batch 200, Loss: 0.126, Acc: 98.434%
# Epoch 78, Batch 300, Loss: 0.094, Acc: 98.328%
# Class 0 has been 100% correctly predicted.
# Class 13 has been 100% correctly predicted.
# Class 32 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 42 has been 100% correctly predicted.
# Class 44 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 54 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 87 has been 100% correctly predicted.
# Class 97 has been 100% correctly predicted.
# Test set: Average loss: 0.7673, Accuracy: 7354/10000 (73.54%)
# New best model saved with accuracy: 73.54%
# Epoch 79, Batch 0, Loss: 40.028, Acc: 96.875%
# Epoch 79, Batch 100, Loss: 0.423, Acc: 98.306%
# Epoch 79, Batch 200, Loss: 0.226, Acc: 98.259%
# Epoch 79, Batch 300, Loss: 0.159, Acc: 98.331%
# Class 0 has been 100% correctly predicted.
# Class 8 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 23 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 35 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 59 has been 100% correctly predicted.
# Class 60 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 70 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Test set: Average loss: 0.7751, Accuracy: 7341/10000 (73.41%)
# Epoch 80, Batch 0, Loss: 50.029, Acc: 96.094%
# Epoch 80, Batch 100, Loss: 0.521, Acc: 98.337%
# Epoch 80, Batch 200, Loss: 0.274, Acc: 98.325%
# Epoch 80, Batch 300, Loss: 0.192, Acc: 98.365%
# Class 3 has been 100% correctly predicted.
# Class 14 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 18 has been 100% correctly predicted.
# Class 22 has been 100% correctly predicted.
# Class 26 has been 100% correctly predicted.
# Class 30 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 49 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 67 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Class 86 has been 100% correctly predicted.
# Test set: Average loss: 0.7705, Accuracy: 7356/10000 (73.56%)
# New best model saved with accuracy: 73.56%
# Epoch 81, Batch 0, Loss: 20.034, Acc: 98.438%
# Epoch 81, Batch 100, Loss: 0.222, Acc: 98.577%
# Epoch 81, Batch 200, Loss: 0.123, Acc: 98.570%
# Epoch 81, Batch 300, Loss: 0.091, Acc: 98.513%
# Class 2 has been 100% correctly predicted.
# Class 12 has been 100% correctly predicted.
# Class 15 has been 100% correctly predicted.
# Class 23 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 36 has been 100% correctly predicted.
# Class 37 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 40 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 64 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 74 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Class 85 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Test set: Average loss: 0.7776, Accuracy: 7345/10000 (73.45%)
# Epoch 82, Batch 0, Loss: 10.023, Acc: 99.219%
# Epoch 82, Batch 100, Loss: 0.121, Acc: 98.515%
# Epoch 82, Batch 200, Loss: 0.073, Acc: 98.500%
# Epoch 82, Batch 300, Loss: 0.057, Acc: 98.523%
# Class 2 has been 100% correctly predicted.
# Class 12 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 58 has been 100% correctly predicted.
# Class 67 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.7711, Accuracy: 7362/10000 (73.62%)
# New best model saved with accuracy: 73.62%
# Epoch 83, Batch 0, Loss: 50.029, Acc: 96.094%
# Epoch 83, Batch 100, Loss: 0.517, Acc: 98.747%
# Epoch 83, Batch 200, Loss: 0.271, Acc: 98.628%
# Epoch 83, Batch 300, Loss: 0.189, Acc: 98.656%
# Class 12 has been 100% correctly predicted.
# Class 15 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 25 has been 100% correctly predicted.
# Class 26 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 37 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 42 has been 100% correctly predicted.
# Class 55 has been 100% correctly predicted.
# Class 64 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 90 has been 100% correctly predicted.
# Class 92 has been 100% correctly predicted.
# Class 97 has been 100% correctly predicted.
# Test set: Average loss: 0.7736, Accuracy: 7362/10000 (73.62%)
# Epoch 84, Batch 0, Loss: 50.037, Acc: 96.094%
# Epoch 84, Batch 100, Loss: 0.517, Acc: 98.677%
# Epoch 84, Batch 200, Loss: 0.271, Acc: 98.745%
# Epoch 84, Batch 300, Loss: 0.189, Acc: 98.624%
# Class 2 has been 100% correctly predicted.
# Class 9 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 33 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 35 has been 100% correctly predicted.
# Class 42 has been 100% correctly predicted.
# Class 49 has been 100% correctly predicted.
# Class 72 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 86 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Class 98 has been 100% correctly predicted.
# Test set: Average loss: 0.7791, Accuracy: 7351/10000 (73.51%)
# Epoch 85, Batch 0, Loss: 30.020, Acc: 97.656%
# Epoch 85, Batch 100, Loss: 0.319, Acc: 98.708%
# Epoch 85, Batch 200, Loss: 0.172, Acc: 98.577%
# Epoch 85, Batch 300, Loss: 0.123, Acc: 98.591%
# Class 39 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 74 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 80 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Class 90 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Class 97 has been 100% correctly predicted.
# Test set: Average loss: 0.7760, Accuracy: 7357/10000 (73.57%)
# Epoch 86, Batch 0, Loss: 10.019, Acc: 99.219%
# Epoch 86, Batch 100, Loss: 0.121, Acc: 98.654%
# Epoch 86, Batch 200, Loss: 0.071, Acc: 98.694%
# Epoch 86, Batch 300, Loss: 0.055, Acc: 98.669%
# Class 1 has been 100% correctly predicted.
# Class 5 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 36 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 43 has been 100% correctly predicted.
# Class 50 has been 100% correctly predicted.
# Class 59 has been 100% correctly predicted.
# Class 72 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Class 90 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.7773, Accuracy: 7336/10000 (73.36%)
# Epoch 87, Batch 0, Loss: 10.020, Acc: 99.219%
# Epoch 87, Batch 100, Loss: 0.121, Acc: 98.677%
# Epoch 87, Batch 200, Loss: 0.071, Acc: 98.671%
# Epoch 87, Batch 300, Loss: 0.055, Acc: 98.630%
# Class 1 has been 100% correctly predicted.
# Class 4 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 24 has been 100% correctly predicted.
# Class 25 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 58 has been 100% correctly predicted.
# Class 60 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Class 93 has been 100% correctly predicted.
# Test set: Average loss: 0.7758, Accuracy: 7364/10000 (73.64%)
# New best model saved with accuracy: 73.64%
# Epoch 88, Batch 0, Loss: 0.018, Acc: 100.000%
# Epoch 88, Batch 100, Loss: 0.020, Acc: 98.871%
# Epoch 88, Batch 200, Loss: 0.021, Acc: 98.745%
# Epoch 88, Batch 300, Loss: 0.021, Acc: 98.733%
# Class 25 has been 100% correctly predicted.
# Class 26 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 43 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 58 has been 100% correctly predicted.
# Class 62 has been 100% correctly predicted.
# Class 65 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Class 96 has been 100% correctly predicted.
# Test set: Average loss: 0.7780, Accuracy: 7349/10000 (73.49%)
# Epoch 89, Batch 0, Loss: 10.014, Acc: 99.219%
# Epoch 89, Batch 100, Loss: 0.120, Acc: 98.685%
# Epoch 89, Batch 200, Loss: 0.071, Acc: 98.647%
# Epoch 89, Batch 300, Loss: 0.054, Acc: 98.705%
# Class 3 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 22 has been 100% correctly predicted.
# Class 25 has been 100% correctly predicted.
# Class 32 has been 100% correctly predicted.
# Class 48 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 81 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Class 90 has been 100% correctly predicted.
# Class 97 has been 100% correctly predicted.
# Test set: Average loss: 0.7801, Accuracy: 7342/10000 (73.42%)
# Epoch 90, Batch 0, Loss: 30.017, Acc: 97.656%
# Epoch 90, Batch 100, Loss: 0.317, Acc: 98.778%
# Epoch 90, Batch 200, Loss: 0.169, Acc: 98.892%
# Epoch 90, Batch 300, Loss: 0.119, Acc: 98.889%
# Class 6 has been 100% correctly predicted.
# Class 15 has been 100% correctly predicted.
# Class 24 has been 100% correctly predicted.
# Class 37 has been 100% correctly predicted.
# Class 40 has been 100% correctly predicted.
# Class 45 has been 100% correctly predicted.
# Class 55 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Class 93 has been 100% correctly predicted.
# Test set: Average loss: 0.7820, Accuracy: 7356/10000 (73.56%)
# Epoch 91, Batch 0, Loss: 20.018, Acc: 98.438%
# Epoch 91, Batch 100, Loss: 0.218, Acc: 98.909%
# Epoch 91, Batch 200, Loss: 0.119, Acc: 98.916%
# Epoch 91, Batch 300, Loss: 0.087, Acc: 98.809%
# Class 5 has been 100% correctly predicted.
# Class 10 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 26 has been 100% correctly predicted.
# Class 30 has been 100% correctly predicted.
# Class 42 has been 100% correctly predicted.
# Class 60 has been 100% correctly predicted.
# Class 73 has been 100% correctly predicted.
# Class 90 has been 100% correctly predicted.
# Class 93 has been 100% correctly predicted.
# Class 94 has been 100% correctly predicted.
# Class 95 has been 100% correctly predicted.
# Test set: Average loss: 0.7822, Accuracy: 7356/10000 (73.56%)
# Epoch 92, Batch 0, Loss: 20.016, Acc: 98.438%
# Epoch 92, Batch 100, Loss: 0.216, Acc: 99.010%
# Epoch 92, Batch 200, Loss: 0.118, Acc: 99.048%
# Epoch 92, Batch 300, Loss: 0.085, Acc: 99.079%
# Class 1 has been 100% correctly predicted.
# Class 2 has been 100% correctly predicted.
# Class 3 has been 100% correctly predicted.
# Class 6 has been 100% correctly predicted.
# Class 20 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 44 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 64 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.7785, Accuracy: 7362/10000 (73.62%)
# Epoch 93, Batch 0, Loss: 0.017, Acc: 100.000%
# Epoch 93, Batch 100, Loss: 0.019, Acc: 98.863%
# Epoch 93, Batch 200, Loss: 0.019, Acc: 98.923%
# Epoch 93, Batch 300, Loss: 0.019, Acc: 98.933%
# Class 7 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 20 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 32 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 56 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 76 has been 100% correctly predicted.
# Class 78 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Class 92 has been 100% correctly predicted.
# Test set: Average loss: 0.7774, Accuracy: 7365/10000 (73.65%)
# New best model saved with accuracy: 73.65%
# Epoch 94, Batch 0, Loss: 20.023, Acc: 98.438%
# Epoch 94, Batch 100, Loss: 0.217, Acc: 98.824%
# Epoch 94, Batch 200, Loss: 0.118, Acc: 98.939%
# Epoch 94, Batch 300, Loss: 0.085, Acc: 98.907%
# Class 1 has been 100% correctly predicted.
# Class 6 has been 100% correctly predicted.
# Class 10 has been 100% correctly predicted.
# Class 12 has been 100% correctly predicted.
# Class 18 has been 100% correctly predicted.
# Class 19 has been 100% correctly predicted.
# Class 23 has been 100% correctly predicted.
# Class 26 has been 100% correctly predicted.
# Class 27 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 34 has been 100% correctly predicted.
# Class 40 has been 100% correctly predicted.
# Class 46 has been 100% correctly predicted.
# Class 58 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 67 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Class 84 has been 100% correctly predicted.
# Class 86 has been 100% correctly predicted.
# Test set: Average loss: 0.7780, Accuracy: 7354/10000 (73.54%)
# Epoch 95, Batch 0, Loss: 0.013, Acc: 100.000%
# Epoch 95, Batch 100, Loss: 0.019, Acc: 99.064%
# Epoch 95, Batch 200, Loss: 0.019, Acc: 99.021%
# Epoch 95, Batch 300, Loss: 0.019, Acc: 98.957%
# Class 3 has been 100% correctly predicted.
# Class 7 has been 100% correctly predicted.
# Class 14 has been 100% correctly predicted.
# Class 17 has been 100% correctly predicted.
# Class 21 has been 100% correctly predicted.
# Class 22 has been 100% correctly predicted.
# Class 24 has been 100% correctly predicted.
# Class 31 has been 100% correctly predicted.
# Class 36 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 77 has been 100% correctly predicted.
# Class 85 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Test set: Average loss: 0.7795, Accuracy: 7362/10000 (73.62%)
# Epoch 96, Batch 0, Loss: 0.009, Acc: 100.000%
# Epoch 96, Batch 100, Loss: 0.020, Acc: 98.979%
# Epoch 96, Batch 200, Loss: 0.019, Acc: 98.986%
# Epoch 96, Batch 300, Loss: 0.019, Acc: 98.957%
# Class 2 has been 100% correctly predicted.
# Class 12 has been 100% correctly predicted.
# Class 20 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 38 has been 100% correctly predicted.
# Class 44 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 55 has been 100% correctly predicted.
# Class 57 has been 100% correctly predicted.
# Class 75 has been 100% correctly predicted.
# Class 79 has been 100% correctly predicted.
# Class 81 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Class 85 has been 100% correctly predicted.
# Class 89 has been 100% correctly predicted.
# Class 90 has been 100% correctly predicted.
# Test set: Average loss: 0.7796, Accuracy: 7349/10000 (73.49%)
# Epoch 97, Batch 0, Loss: 0.009, Acc: 100.000%
# Epoch 97, Batch 100, Loss: 0.018, Acc: 98.902%
# Epoch 97, Batch 200, Loss: 0.019, Acc: 98.919%
# Epoch 97, Batch 300, Loss: 0.019, Acc: 98.941%
# Class 10 has been 100% correctly predicted.
# Class 11 has been 100% correctly predicted.
# Class 14 has been 100% correctly predicted.
# Class 20 has been 100% correctly predicted.
# Class 38 has been 100% correctly predicted.
# Class 44 has been 100% correctly predicted.
# Class 54 has been 100% correctly predicted.
# Class 60 has been 100% correctly predicted.
# Class 68 has been 100% correctly predicted.
# Class 82 has been 100% correctly predicted.
# Class 88 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.7779, Accuracy: 7378/10000 (73.78%)
# New best model saved with accuracy: 73.78%
# Epoch 98, Batch 0, Loss: 0.018, Acc: 100.000%
# Epoch 98, Batch 100, Loss: 0.018, Acc: 99.072%
# Epoch 98, Batch 200, Loss: 0.019, Acc: 98.997%
# Epoch 98, Batch 300, Loss: 0.019, Acc: 98.988%
# Class 21 has been 100% correctly predicted.
# Class 29 has been 100% correctly predicted.
# Class 35 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 41 has been 100% correctly predicted.
# Class 42 has been 100% correctly predicted.
# Class 49 has been 100% correctly predicted.
# Class 53 has been 100% correctly predicted.
# Class 63 has been 100% correctly predicted.
# Class 66 has been 100% correctly predicted.
# Class 69 has been 100% correctly predicted.
# Class 74 has been 100% correctly predicted.
# Class 78 has been 100% correctly predicted.
# Class 91 has been 100% correctly predicted.
# Test set: Average loss: 0.7772, Accuracy: 7354/10000 (73.54%)
# Epoch 99, Batch 0, Loss: 10.022, Acc: 99.219%
# Epoch 99, Batch 100, Loss: 0.118, Acc: 98.878%
# Epoch 99, Batch 200, Loss: 0.068, Acc: 98.896%
# Epoch 99, Batch 300, Loss: 0.052, Acc: 98.894%
# Class 1 has been 100% correctly predicted.
# Class 4 has been 100% correctly predicted.
# Class 12 has been 100% correctly predicted.
# Class 18 has been 100% correctly predicted.
# Class 20 has been 100% correctly predicted.
# Class 26 has been 100% correctly predicted.
# Class 39 has been 100% correctly predicted.
# Class 46 has been 100% correctly predicted.
# Class 51 has been 100% correctly predicted.
# Class 54 has been 100% correctly predicted.
# Class 59 has been 100% correctly predicted.
# Class 78 has been 100% correctly predicted.
# Class 80 has been 100% correctly predicted.
# Class 83 has been 100% correctly predicted.
# Class 92 has been 100% correctly predicted.
# Class 95 has been 100% correctly predicted.
# Test set: Average loss: 0.7779, Accuracy: 7354/10000 (73.54%)
