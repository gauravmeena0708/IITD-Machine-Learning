# %%
# !cp -r /kaggle/input/col774a3/* /kaggle/working/

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import StepLR
import os
import pickle
import pandas as pd
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import StepLR
import os
import pickle
import pandas as pd
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset

# Set a confidence threshold (will be dynamically generated for each class)
PENALTY_WEIGHT = 10  # Weight for penalizing incorrect predictions after 50% accuracy
SAVE_PATH = './saved_models/'  # Directory to save model checkpoints
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# Focal Loss for handling imbalanced datasets
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, outputs, targets):
        BCE_loss = F.cross_entropy(outputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)  # Get the probability
        focal_loss = self.alpha * (1-pt)**self.gamma * BCE_loss
        return focal_loss.mean()

# Custom Loss Function with Focal Loss and Penalty for Wrong Predictions after 50% Accuracy
def custom_loss_function(outputs, targets, current_accuracy):
    # Apply softmax to get probabilities
    probabilities = F.softmax(outputs, dim=1)
    
    # Get the max probability (confidence) and corresponding predicted class
    confidences, predicted_classes = torch.max(probabilities, dim=1)
    
    # Calculate the Focal Loss for class imbalance
    focal_loss = FocalLoss()(outputs, targets)
    
    # Heavily penalize wrong argmax predictions if training accuracy > 50%
    wrong_predictions = (predicted_classes != targets).float()
    if current_accuracy > 0.5:
        wrong_prediction_penalty = PENALTY_WEIGHT * wrong_predictions.sum()
    else:
        wrong_prediction_penalty = 0

    # Calculate the total loss
    total_loss = focal_loss + wrong_prediction_penalty
    return total_loss

# WideResNeXt Block
class WideResNeXtBlock(nn.Module):
    expansion = 2  # Expansion factor for WideResNeXt

    def __init__(self, in_planes, planes, stride=1, cardinality=32, widen_factor=2):
        super(WideResNeXtBlock, self).__init__()
        D = cardinality * widen_factor
        self.conv1 = nn.Conv2d(in_planes, D, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(D)
        self.conv2 = nn.Conv2d(D, D, kernel_size=3, stride=stride, padding=1, groups=cardinality, bias=False)
        self.bn2 = nn.BatchNorm2d(D)
        self.conv3 = nn.Conv2d(D, planes * WideResNeXtBlock.expansion, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes * WideResNeXtBlock.expansion)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes * WideResNeXtBlock.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * WideResNeXtBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * WideResNeXtBlock.expansion)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = torch.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# WideResNeXt Model
class WideResNeXt(nn.Module):
    def __init__(self, block, num_blocks, cardinality=32, widen_factor=2, num_classes=100):
        super(WideResNeXt, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)

        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1, cardinality=cardinality, widen_factor=widen_factor)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2, cardinality=cardinality, widen_factor=widen_factor)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2, cardinality=cardinality, widen_factor=widen_factor)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2, cardinality=cardinality, widen_factor=widen_factor)

        self.linear = nn.Linear(512 * WideResNeXtBlock.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride, cardinality, widen_factor):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride, cardinality, widen_factor))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = torch.nn.functional.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# WideResNeXt-101 Model Definition
def WideResNeXt101():
    return WideResNeXt(WideResNeXtBlock, [3, 4, 23, 3], cardinality=32, widen_factor=2)

# Custom Dataset class for loading CIFAR100 data from .pkl files
class CIFAR100Dataset(Dataset):
    def __init__(self, file_path):
        with open(file_path, 'rb') as f:
            self.data = pickle.load(f)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image, label = self.data[idx]
        return image, label

# Training function
def train_with_penalty(epoch, class_thresholds):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        
        # Calculate the overall training accuracy before updating weights
        probabilities = F.softmax(outputs, dim=1)
        _, predicted_classes = torch.max(probabilities, dim=1)
        correct_predictions = predicted_classes.eq(targets).sum().item()
        total += targets.size(0)
        current_accuracy = correct_predictions / total
        
        # Calculate custom loss with penalties if training accuracy is above 50%
        loss = custom_loss_function(outputs, targets, current_accuracy)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        correct += correct_predictions

        if batch_idx % 100 == 0:
            print(f'Epoch {epoch}, Batch {batch_idx}, Loss: {train_loss / (batch_idx + 1):.3f}, Acc: {100.*correct/total:.3f}%')

# Test function with class-specific thresholds and evaluation
def test_with_class_thresholds(epoch, class_thresholds, test_info_path):
    global best_accuracy
    model.eval()
    correct = 0
    total = 0
    high_conf_correct = 0
    high_conf_total = 0
    
    predictions = []  # Store predictions for submission
    ids = []  # Store corresponding IDs for submission
    
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            probabilities = F.softmax(outputs, dim=1)
            confidences, predicted_classes = torch.max(probabilities, dim=1)
            
            # Count correct predictions
            correct_predictions = predicted_classes.eq(targets).sum().item()
            correct += correct_predictions
            total += targets.size(0)
            
            # Class-specific thresholds
            for i in range(len(inputs)):
                class_idx = predicted_classes[i].item()
                if confidences[i] > class_thresholds[class_idx]:
                    predictions.append((batch_idx * 100 + i, predicted_classes[i].item()))
                else:
                    predictions.append((batch_idx * 100 + i, -1))  # Assign -1 for low-confidence predictions
                
                ids.append(batch_idx * 100 + i)
        
    # Save predictions to CSV
    save_predictions_to_csv(ids, predictions)
    
    # Evaluate using calculate_score
    evaluate_and_print_score(test_info_path, 'submission.csv')

    # Calculate accuracy
    test_accuracy = 100. * correct / total
    print(f"Test Accuracy: {test_accuracy:.2f}%")

# Function to save predictions to CSV
def save_predictions_to_csv(ids, predictions):
    df = pd.DataFrame({'ID': ids, 'Predicted_label': predictions})
    df.to_csv('submission.csv', index=False)
    print("Predictions saved to submission.csv")

# Function to evaluate and print score for each epoch
def evaluate_and_print_score(test_info_path, prediction_file):
    batch_1, batch_2 = evaluate_in_two_sets(test_info_path, prediction_file)
    
    # Print scores for both sets
    print(f"\nBatch 1: Correct: {batch_1['correct']}, Incorrect: {batch_1['incorrect']}, Skipped: {batch_1['skipped']}, Score: {batch_1['score']:.2f}")
    print(f"Batch 2: Correct: {batch_2['correct']}, Incorrect: {batch_2['incorrect']}, Skipped: {batch_2['skipped']}, Score: {batch_2['score']:.2f}")

# Function to calculate the score for predictions
def calculate_score(true_labels: pd.Series, predicted_labels: pd.Series, accuracy_threshold: float = 0.7, gamma: float = 5.0):
    data = pd.DataFrame({'True_label': true_labels, 'Predicted_label': predicted_labels})
    total_skipped = (data['Predicted_label'] == -1).sum()
    filtered_df = data[data['Predicted_label'] != -1]
    
    all_classes = list(range(100))  # Assuming CIFAR-100 dataset with 100 classes
    sum_of_correctly_classified_high_accuracy = 0
    sum_of_correctly_classified_low_accuracy = 0
    total_correct = 0
    total_incorrect = 0
    
    accuracy_per_class = {}
    grouped = filtered_df.groupby('Predicted_label')
    
    for name, group in grouped:
        accuracy = (group['True_label'] == group['Predicted_label']).sum() / len(group)
        accuracy_per_class[name] = accuracy
        total_correct += (group['True_label'] == group['Predicted_label']).sum()
        total_incorrect += (group['True_label'] != group['Predicted_label']).sum()
    
    for cls in all_classes:
        total = len(filtered_df[filtered_df['Predicted_label'] == cls])
        class_accuracy = accuracy_per_class.get(cls, 0.0)
        
        if class_accuracy >= accuracy_threshold:
            sum_of_correctly_classified_high_accuracy += total
        else:
            sum_of_correctly_classified_low_accuracy += total

    final_score = sum_of_correctly_classified_high_accuracy - gamma * sum_of_correctly_classified_low_accuracy
    return final_score, total_correct, total_incorrect, total_skipped

# Function to evaluate the test predictions in two sets
def evaluate_in_two_sets(test_info_path: str, prediction_file: str):
    test_info = pd.read_csv(test_info_path)
    predictions = pd.read_csv(prediction_file)
    merged_data = pd.merge(test_info, predictions, on='ID')
    
    first_half = merged_data[:10000]
    second_half = merged_data[10000:20000]
    
    score_first_half, correct_first_half, incorrect_first_half, skipped_first_half = calculate_score(first_half['True_label'], first_half['Predicted_label'])
    score_second_half, correct_second_half, incorrect_second_half, skipped_second_half = calculate_score(second_half['True_label'], second_half['Predicted_label'])
    
    batch_1 = {
        'total': 10000,
        'correct': correct_first_half,
        'incorrect': incorrect_first_half,
        'skipped': skipped_first_half,
        'score': score_first_half
    }
    
    batch_2 = {
        'total': 10000,
        'correct': correct_second_half,
        'incorrect': incorrect_second_half,
        'skipped': skipped_second_half,
        'score': score_second_half
    }
    
    return batch_1, batch_2

# Generate class-specific thresholds
def generate_class_thresholds(trainloader, target_accuracy=99.99):
    class_confidences = {i: [] for i in range(100)}  # Store confidences per class

    model.eval()
    with torch.no_grad():
        for inputs, targets in trainloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            probabilities = F.softmax(outputs, dim=1)
            confidences, predicted_classes = torch.max(probabilities, dim=1)
            
            for i in range(len(targets)):
                class_idx = targets[i].item()
                class_confidences[class_idx].append(confidences[i].item())

    class_thresholds = {}
    for cls, confidences in class_confidences.items():
        sorted_confidences = sorted(confidences)
        threshold_idx = int(len(sorted_confidences) * (1 - target_accuracy / 100))
        class_thresholds[cls] = sorted_confidences[threshold_idx]
    
    return class_thresholds

# Load datasets
train_dataset = CIFAR100Dataset('train.pkl')
test_dataset = CIFAR100Dataset('test.pkl')

trainloader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
testloader = DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=2)

# Model, loss, optimizer, and scheduler
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = WideResNeXt101().to(device)

optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)

best_accuracy = 0.0

# Generate class-specific thresholds based on 99.99% accuracy
class_thresholds = generate_class_thresholds(trainloader, target_accuracy=99.99)

# Example Training Loop
for epoch in range(0, 100):
    train_with_penalty(epoch, class_thresholds)
    test_with_class_thresholds(epoch, class_thresholds, 'test_info.csv')
    scheduler.step()
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Epoch 0, Batch 0, Loss: 4.785, Acc: 2.344%
# Epoch 0, Batch 100, Loss: 5.084, Acc: 1.214%
# Epoch 0, Batch 200, Loss: 4.711, Acc: 1.994%
# Epoch 0, Batch 300, Loss: 4.473, Acc: 2.824%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 1, Batch 0, Loss: 3.852, Acc: 10.938%
# Epoch 1, Batch 100, Loss: 3.771, Acc: 7.480%
# Epoch 1, Batch 200, Loss: 3.684, Acc: 8.446%
# Epoch 1, Batch 300, Loss: 3.600, Acc: 9.585%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 2, Batch 0, Loss: 3.175, Acc: 24.219%
# Epoch 2, Batch 100, Loss: 3.195, Acc: 16.043%
# Epoch 2, Batch 200, Loss: 3.144, Acc: 16.803%
# Epoch 2, Batch 300, Loss: 3.074, Acc: 17.816%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 3, Batch 0, Loss: 3.018, Acc: 18.750%
# Epoch 3, Batch 100, Loss: 2.735, Acc: 23.615%
# Epoch 3, Batch 200, Loss: 2.693, Acc: 24.436%
# Epoch 3, Batch 300, Loss: 2.634, Acc: 25.628%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 4, Batch 0, Loss: 2.237, Acc: 29.688%
# Epoch 4, Batch 100, Loss: 2.314, Acc: 31.018%
# Epoch 4, Batch 200, Loss: 2.306, Acc: 31.157%
# Epoch 4, Batch 300, Loss: 2.278, Acc: 31.785%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 5, Batch 0, Loss: 1.932, Acc: 43.750%
# Epoch 5, Batch 100, Loss: 2.002, Acc: 36.827%
# Epoch 5, Batch 200, Loss: 2.008, Acc: 36.707%
# Epoch 5, Batch 300, Loss: 1.980, Acc: 37.539%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 6, Batch 0, Loss: 1.436, Acc: 50.000%
# Epoch 6, Batch 100, Loss: 1.706, Acc: 43.278%
# Epoch 6, Batch 200, Loss: 1.740, Acc: 42.320%
# Epoch 6, Batch 300, Loss: 1.742, Acc: 42.439%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 7, Batch 0, Loss: 1.829, Acc: 42.188%
# Epoch 7, Batch 100, Loss: 1.541, Acc: 47.386%
# Epoch 7, Batch 200, Loss: 1.574, Acc: 46.323%
# Epoch 7, Batch 300, Loss: 1.581, Acc: 46.159%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 8, Batch 0, Loss: 551.236, Acc: 57.031%
# Epoch 8, Batch 100, Loss: 6.833, Acc: 50.503%
# Epoch 8, Batch 200, Loss: 4.160, Acc: 49.635%
# Epoch 8, Batch 300, Loss: 3.274, Acc: 49.188%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 9, Batch 0, Loss: 531.284, Acc: 58.594%
# Epoch 9, Batch 100, Loss: 6.566, Acc: 52.251%
# Epoch 9, Batch 200, Loss: 3.957, Acc: 52.235%
# Epoch 9, Batch 300, Loss: 3.095, Acc: 51.786%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 10, Batch 0, Loss: 541.162, Acc: 57.812%
# Epoch 10, Batch 100, Loss: 6.507, Acc: 56.753%
# Epoch 10, Batch 200, Loss: 3.895, Acc: 55.119%
# Epoch 10, Batch 300, Loss: 3.031, Acc: 54.251%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 11, Batch 0, Loss: 551.017, Acc: 57.031%
# Epoch 11, Batch 100, Loss: 6.529, Acc: 58.300%
# Epoch 11, Batch 200, Loss: 3.870, Acc: 56.977%
# Epoch 11, Batch 300, Loss: 2.984, Acc: 56.271%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 12, Batch 0, Loss: 490.803, Acc: 61.719%
# Epoch 12, Batch 100, Loss: 5.873, Acc: 59.599%
# Epoch 12, Batch 200, Loss: 3.500, Acc: 58.664%
# Epoch 12, Batch 300, Loss: 2.709, Acc: 58.124%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 13, Batch 0, Loss: 410.762, Acc: 67.969%
# Epoch 13, Batch 100, Loss: 5.012, Acc: 61.750%
# Epoch 13, Batch 200, Loss: 3.041, Acc: 60.510%
# Epoch 13, Batch 300, Loss: 2.388, Acc: 59.775%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 14, Batch 0, Loss: 390.774, Acc: 69.531%
# Epoch 14, Batch 100, Loss: 4.761, Acc: 62.809%
# Epoch 14, Batch 200, Loss: 2.906, Acc: 61.081%
# Epoch 14, Batch 300, Loss: 2.288, Acc: 60.520%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 15, Batch 0, Loss: 480.821, Acc: 62.500%
# Epoch 15, Batch 100, Loss: 5.600, Acc: 64.952%
# Epoch 15, Batch 200, Loss: 3.310, Acc: 62.947%
# Epoch 15, Batch 300, Loss: 2.541, Acc: 62.285%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 16, Batch 0, Loss: 510.831, Acc: 60.156%
# Epoch 16, Batch 100, Loss: 5.893, Acc: 64.743%
# Epoch 16, Batch 200, Loss: 3.434, Acc: 63.351%
# Epoch 16, Batch 300, Loss: 2.618, Acc: 62.565%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 17, Batch 0, Loss: 430.940, Acc: 66.406%
# Epoch 17, Batch 100, Loss: 5.037, Acc: 66.963%
# Epoch 17, Batch 200, Loss: 2.998, Acc: 64.366%
# Epoch 17, Batch 300, Loss: 2.325, Acc: 63.320%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 18, Batch 0, Loss: 450.715, Acc: 64.844%
# Epoch 18, Batch 100, Loss: 5.216, Acc: 66.808%
# Epoch 18, Batch 200, Loss: 3.075, Acc: 64.785%
# Epoch 18, Batch 300, Loss: 2.365, Acc: 64.016%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 19, Batch 0, Loss: 400.730, Acc: 68.750%
# Epoch 19, Batch 100, Loss: 4.699, Acc: 67.721%
# Epoch 19, Batch 200, Loss: 2.792, Acc: 65.963%
# Epoch 19, Batch 300, Loss: 2.167, Acc: 64.852%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 20, Batch 0, Loss: 380.680, Acc: 70.312%
# Epoch 20, Batch 100, Loss: 4.480, Acc: 68.851%
# Epoch 20, Batch 200, Loss: 2.674, Acc: 66.752%
# Epoch 20, Batch 300, Loss: 2.087, Acc: 65.363%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 21, Batch 0, Loss: 420.763, Acc: 67.188%
# Epoch 21, Batch 100, Loss: 4.861, Acc: 68.943%
# Epoch 21, Batch 200, Loss: 2.864, Acc: 66.663%
# Epoch 21, Batch 300, Loss: 2.200, Acc: 65.703%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 22, Batch 0, Loss: 320.657, Acc: 75.000%
# Epoch 22, Batch 100, Loss: 3.859, Acc: 69.206%
# Epoch 22, Batch 200, Loss: 2.343, Acc: 67.300%
# Epoch 22, Batch 300, Loss: 1.861, Acc: 66.053%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 23, Batch 0, Loss: 400.700, Acc: 68.750%
# Epoch 23, Batch 100, Loss: 4.652, Acc: 69.748%
# Epoch 23, Batch 200, Loss: 2.738, Acc: 67.774%
# Epoch 23, Batch 300, Loss: 2.110, Acc: 66.518%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 24, Batch 0, Loss: 380.574, Acc: 70.312%
# Epoch 24, Batch 100, Loss: 4.435, Acc: 69.694%
# Epoch 24, Batch 200, Loss: 2.623, Acc: 67.825%
# Epoch 24, Batch 300, Loss: 2.032, Acc: 66.780%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.00%
# Epoch 25, Batch 0, Loss: 300.525, Acc: 76.562%
# Epoch 25, Batch 100, Loss: 3.643, Acc: 69.848%
# Epoch 25, Batch 200, Loss: 2.195, Acc: 68.859%
# Epoch 25, Batch 300, Loss: 1.743, Acc: 67.665%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 26, Batch 0, Loss: 290.500, Acc: 77.344%
# Epoch 26, Batch 100, Loss: 3.475, Acc: 72.092%
# Epoch 26, Batch 200, Loss: 2.124, Acc: 69.384%
# Epoch 26, Batch 300, Loss: 1.689, Acc: 68.252%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 27, Batch 0, Loss: 290.571, Acc: 77.344%
# Epoch 27, Batch 100, Loss: 3.484, Acc: 71.890%
# Epoch 27, Batch 200, Loss: 2.133, Acc: 69.220%
# Epoch 27, Batch 300, Loss: 1.692, Acc: 68.028%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 28, Batch 0, Loss: 360.535, Acc: 71.875%
# Epoch 28, Batch 100, Loss: 4.192, Acc: 71.334%
# Epoch 28, Batch 200, Loss: 2.471, Acc: 69.570%
# Epoch 28, Batch 300, Loss: 1.911, Acc: 68.514%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 29, Batch 0, Loss: 370.635, Acc: 71.094%
# Epoch 29, Batch 100, Loss: 4.280, Acc: 72.138%
# Epoch 29, Batch 200, Loss: 2.515, Acc: 69.862%
# Epoch 29, Batch 300, Loss: 1.937, Acc: 68.776%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 30, Batch 0, Loss: 370.512, Acc: 71.094%
# Epoch 30, Batch 100, Loss: 4.060, Acc: 81.196%
# Epoch 30, Batch 200, Loss: 2.176, Acc: 83.570%
# Epoch 30, Batch 300, Loss: 1.535, Acc: 84.770%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 31, Batch 0, Loss: 70.123, Acc: 94.531%
# Epoch 31, Batch 100, Loss: 0.843, Acc: 92.180%
# Epoch 31, Batch 200, Loss: 0.499, Acc: 92.071%
# Epoch 31, Batch 300, Loss: 0.381, Acc: 92.084%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 32, Batch 0, Loss: 60.122, Acc: 95.312%
# Epoch 32, Batch 100, Loss: 0.690, Acc: 95.011%
# Epoch 32, Batch 200, Loss: 0.393, Acc: 94.963%
# Epoch 32, Batch 300, Loss: 0.293, Acc: 94.996%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 33, Batch 0, Loss: 50.090, Acc: 96.094%
# Epoch 33, Batch 100, Loss: 0.556, Acc: 96.937%
# Epoch 33, Batch 200, Loss: 0.310, Acc: 97.046%
# Epoch 33, Batch 300, Loss: 0.227, Acc: 97.023%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 34, Batch 0, Loss: 10.026, Acc: 99.219%
# Epoch 34, Batch 100, Loss: 0.142, Acc: 98.120%
# Epoch 34, Batch 200, Loss: 0.093, Acc: 98.045%
# Epoch 34, Batch 300, Loss: 0.076, Acc: 98.020%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 35, Batch 0, Loss: 20.037, Acc: 98.438%
# Epoch 35, Batch 100, Loss: 0.230, Acc: 98.933%
# Epoch 35, Batch 200, Loss: 0.131, Acc: 98.892%
# Epoch 35, Batch 300, Loss: 0.098, Acc: 98.796%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 36, Batch 0, Loss: 10.023, Acc: 99.219%
# Epoch 36, Batch 100, Loss: 0.124, Acc: 99.103%
# Epoch 36, Batch 200, Loss: 0.074, Acc: 99.168%
# Epoch 36, Batch 300, Loss: 0.057, Acc: 99.185%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 37, Batch 0, Loss: 0.014, Acc: 100.000%
# Epoch 37, Batch 100, Loss: 0.019, Acc: 99.443%
# Epoch 37, Batch 200, Loss: 0.019, Acc: 99.401%
# Epoch 37, Batch 300, Loss: 0.019, Acc: 99.346%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 38, Batch 0, Loss: 10.018, Acc: 99.219%
# Epoch 38, Batch 100, Loss: 0.115, Acc: 99.636%
# Epoch 38, Batch 200, Loss: 0.065, Acc: 99.662%
# Epoch 38, Batch 300, Loss: 0.049, Acc: 99.600%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 39, Batch 0, Loss: 0.013, Acc: 100.000%
# Epoch 39, Batch 100, Loss: 0.013, Acc: 99.768%
# Epoch 39, Batch 200, Loss: 0.013, Acc: 99.778%
# Epoch 39, Batch 300, Loss: 0.014, Acc: 99.751%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 40, Batch 0, Loss: 0.008, Acc: 100.000%
# Epoch 40, Batch 100, Loss: 0.012, Acc: 99.838%
# Epoch 40, Batch 200, Loss: 0.012, Acc: 99.825%
# Epoch 40, Batch 300, Loss: 0.012, Acc: 99.834%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 41, Batch 0, Loss: 0.007, Acc: 100.000%
# Epoch 41, Batch 100, Loss: 0.011, Acc: 99.853%
# Epoch 41, Batch 200, Loss: 0.011, Acc: 99.860%
# Epoch 41, Batch 300, Loss: 0.011, Acc: 99.849%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 42, Batch 0, Loss: 10.015, Acc: 99.219%
# Epoch 42, Batch 100, Loss: 0.108, Acc: 99.915%
# Epoch 42, Batch 200, Loss: 0.059, Acc: 99.883%
# Epoch 42, Batch 300, Loss: 0.043, Acc: 99.894%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 43, Batch 0, Loss: 0.008, Acc: 100.000%
# Epoch 43, Batch 100, Loss: 0.008, Acc: 99.969%
# Epoch 43, Batch 200, Loss: 0.009, Acc: 99.973%
# Epoch 43, Batch 300, Loss: 0.009, Acc: 99.958%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 44, Batch 0, Loss: 0.007, Acc: 100.000%
# Epoch 44, Batch 100, Loss: 0.008, Acc: 99.946%
# Epoch 44, Batch 200, Loss: 0.008, Acc: 99.953%
# Epoch 44, Batch 300, Loss: 0.008, Acc: 99.940%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 45, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 45, Batch 100, Loss: 0.007, Acc: 99.969%
# Epoch 45, Batch 200, Loss: 0.007, Acc: 99.969%
# Epoch 45, Batch 300, Loss: 0.008, Acc: 99.969%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 46, Batch 0, Loss: 0.007, Acc: 100.000%
# Epoch 46, Batch 100, Loss: 0.007, Acc: 99.969%
# Epoch 46, Batch 200, Loss: 0.007, Acc: 99.949%
# Epoch 46, Batch 300, Loss: 0.007, Acc: 99.958%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 47, Batch 0, Loss: 0.006, Acc: 100.000%
# Epoch 47, Batch 100, Loss: 0.007, Acc: 99.985%
# Epoch 47, Batch 200, Loss: 0.007, Acc: 99.977%
# Epoch 47, Batch 300, Loss: 0.007, Acc: 99.971%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 48, Batch 0, Loss: 0.007, Acc: 100.000%
# Epoch 48, Batch 100, Loss: 0.006, Acc: 99.961%
# Epoch 48, Batch 200, Loss: 0.006, Acc: 99.969%
# Epoch 48, Batch 300, Loss: 0.007, Acc: 99.969%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 49, Batch 0, Loss: 0.006, Acc: 100.000%
# Epoch 49, Batch 100, Loss: 0.006, Acc: 99.954%
# Epoch 49, Batch 200, Loss: 0.006, Acc: 99.965%
# Epoch 49, Batch 300, Loss: 0.007, Acc: 99.958%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 50, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 50, Batch 100, Loss: 0.006, Acc: 99.969%
# Epoch 50, Batch 200, Loss: 0.006, Acc: 99.984%
# Epoch 50, Batch 300, Loss: 0.006, Acc: 99.982%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 51, Batch 0, Loss: 0.006, Acc: 100.000%
# Epoch 51, Batch 100, Loss: 0.006, Acc: 99.969%
# Epoch 51, Batch 200, Loss: 0.006, Acc: 99.973%
# Epoch 51, Batch 300, Loss: 0.006, Acc: 99.977%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 52, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 52, Batch 100, Loss: 0.005, Acc: 99.977%
# Epoch 52, Batch 200, Loss: 0.006, Acc: 99.981%
# Epoch 52, Batch 300, Loss: 0.006, Acc: 99.982%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 53, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 53, Batch 100, Loss: 0.005, Acc: 100.000%
# Epoch 53, Batch 200, Loss: 0.006, Acc: 99.996%
# Epoch 53, Batch 300, Loss: 0.006, Acc: 99.992%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 54, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 54, Batch 100, Loss: 0.005, Acc: 99.992%
# Epoch 54, Batch 200, Loss: 0.006, Acc: 99.981%
# Epoch 54, Batch 300, Loss: 0.006, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 55, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 55, Batch 100, Loss: 0.005, Acc: 99.992%
# Epoch 55, Batch 200, Loss: 0.005, Acc: 99.996%
# Epoch 55, Batch 300, Loss: 0.005, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 56, Batch 0, Loss: 0.007, Acc: 100.000%
# Epoch 56, Batch 100, Loss: 0.005, Acc: 99.977%
# Epoch 56, Batch 200, Loss: 0.005, Acc: 99.977%
# Epoch 56, Batch 300, Loss: 0.006, Acc: 99.971%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 57, Batch 0, Loss: 0.006, Acc: 100.000%
# Epoch 57, Batch 100, Loss: 0.005, Acc: 99.977%
# Epoch 57, Batch 200, Loss: 0.005, Acc: 99.977%
# Epoch 57, Batch 300, Loss: 0.005, Acc: 99.982%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 58, Batch 0, Loss: 0.008, Acc: 100.000%
# Epoch 58, Batch 100, Loss: 0.005, Acc: 99.992%
# Epoch 58, Batch 200, Loss: 0.005, Acc: 99.977%
# Epoch 58, Batch 300, Loss: 0.005, Acc: 99.977%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 59, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 59, Batch 100, Loss: 0.005, Acc: 99.969%
# Epoch 59, Batch 200, Loss: 0.005, Acc: 99.981%
# Epoch 59, Batch 300, Loss: 0.005, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 60, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 60, Batch 100, Loss: 0.005, Acc: 99.977%
# Epoch 60, Batch 200, Loss: 0.005, Acc: 99.988%
# Epoch 60, Batch 300, Loss: 0.005, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 61, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 61, Batch 100, Loss: 0.004, Acc: 99.977%
# Epoch 61, Batch 200, Loss: 0.005, Acc: 99.977%
# Epoch 61, Batch 300, Loss: 0.004, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 62, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 62, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 62, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 62, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 63, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 63, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 63, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 63, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 64, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 64, Batch 100, Loss: 0.005, Acc: 99.969%
# Epoch 64, Batch 200, Loss: 0.004, Acc: 99.981%
# Epoch 64, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 65, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 65, Batch 100, Loss: 0.004, Acc: 100.000%
# Epoch 65, Batch 200, Loss: 0.004, Acc: 100.000%
# Epoch 65, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 66, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 66, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 66, Batch 200, Loss: 0.004, Acc: 99.981%
# Epoch 66, Batch 300, Loss: 0.004, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 67, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 67, Batch 100, Loss: 0.004, Acc: 100.000%
# Epoch 67, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 67, Batch 300, Loss: 0.004, Acc: 99.992%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 68, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 68, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 68, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 68, Batch 300, Loss: 0.004, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 69, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 69, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 69, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 69, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 70, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 70, Batch 100, Loss: 0.004, Acc: 99.977%
# Epoch 70, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 70, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 71, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 71, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 71, Batch 200, Loss: 0.004, Acc: 99.984%
# Epoch 71, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 72, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 72, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 72, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 72, Batch 300, Loss: 0.004, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 73, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 73, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 73, Batch 200, Loss: 0.004, Acc: 99.984%
# Epoch 73, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 74, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 74, Batch 100, Loss: 0.004, Acc: 99.977%
# Epoch 74, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 74, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 75, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 75, Batch 100, Loss: 0.004, Acc: 100.000%
# Epoch 75, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 75, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 76, Batch 0, Loss: 10.005, Acc: 99.219%
# Epoch 76, Batch 100, Loss: 0.103, Acc: 99.985%
# Epoch 76, Batch 200, Loss: 0.054, Acc: 99.988%
# Epoch 76, Batch 300, Loss: 0.037, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 77, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 77, Batch 100, Loss: 0.004, Acc: 100.000%
# Epoch 77, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 77, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 78, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 78, Batch 100, Loss: 0.004, Acc: 100.000%
# Epoch 78, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 78, Batch 300, Loss: 0.004, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 79, Batch 0, Loss: 0.005, Acc: 100.000%
# Epoch 79, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 79, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 79, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 80, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 80, Batch 100, Loss: 0.004, Acc: 99.977%
# Epoch 80, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 80, Batch 300, Loss: 0.004, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 81, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 81, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 81, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 81, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 82, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 82, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 82, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 82, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 83, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 83, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 83, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 83, Batch 300, Loss: 0.004, Acc: 99.992%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 84, Batch 0, Loss: 10.005, Acc: 99.219%
# Epoch 84, Batch 100, Loss: 0.103, Acc: 99.992%
# Epoch 84, Batch 200, Loss: 0.054, Acc: 99.988%
# Epoch 84, Batch 300, Loss: 0.037, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 85, Batch 0, Loss: 0.006, Acc: 100.000%
# Epoch 85, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 85, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 85, Batch 300, Loss: 0.004, Acc: 99.992%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 86, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 86, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 86, Batch 200, Loss: 0.004, Acc: 99.984%
# Epoch 86, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 87, Batch 0, Loss: 10.006, Acc: 99.219%
# Epoch 87, Batch 100, Loss: 0.103, Acc: 99.969%
# Epoch 87, Batch 200, Loss: 0.054, Acc: 99.977%
# Epoch 87, Batch 300, Loss: 0.037, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 88, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 88, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 88, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 88, Batch 300, Loss: 0.004, Acc: 99.992%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 89, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 89, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 89, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 89, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 90, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 90, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 90, Batch 200, Loss: 0.004, Acc: 99.984%
# Epoch 90, Batch 300, Loss: 0.004, Acc: 99.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 91, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 91, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 91, Batch 200, Loss: 0.004, Acc: 99.992%
# Epoch 91, Batch 300, Loss: 0.004, Acc: 99.995%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 92, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 92, Batch 100, Loss: 0.004, Acc: 100.000%
# Epoch 92, Batch 200, Loss: 0.004, Acc: 99.996%
# Epoch 92, Batch 300, Loss: 0.004, Acc: 99.995%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 93, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 93, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 93, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 93, Batch 300, Loss: 0.004, Acc: 99.987%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 94, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 94, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 94, Batch 200, Loss: 0.004, Acc: 99.984%
# Epoch 94, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 95, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 95, Batch 100, Loss: 0.004, Acc: 99.985%
# Epoch 95, Batch 200, Loss: 0.004, Acc: 99.984%
# Epoch 95, Batch 300, Loss: 0.004, Acc: 99.979%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 96, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 96, Batch 100, Loss: 0.004, Acc: 99.961%
# Epoch 96, Batch 200, Loss: 0.004, Acc: 99.973%
# Epoch 96, Batch 300, Loss: 0.004, Acc: 99.982%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 97, Batch 0, Loss: 0.004, Acc: 100.000%
# Epoch 97, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 97, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 97, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 98, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 98, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 98, Batch 200, Loss: 0.004, Acc: 99.988%
# Epoch 98, Batch 300, Loss: 0.004, Acc: 99.990%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
# Epoch 99, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 99, Batch 100, Loss: 0.004, Acc: 99.992%
# Epoch 99, Batch 200, Loss: 0.004, Acc: 99.996%
# Epoch 99, Batch 300, Loss: 0.004, Acc: 99.995%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Batch 2: Correct: 0, Incorrect: 10000, Skipped: 0, Score: 0.00
# Test Accuracy: 0.01%
