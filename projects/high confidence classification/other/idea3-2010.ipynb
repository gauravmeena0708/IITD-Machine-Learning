# %%
# !cp -r /kaggle/input/col774a3/* /kaggle/working/

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import StepLR
import os
import pickle
import pandas as pd
from torch.utils.data import DataLoader, Dataset

# Set a confidence threshold (will be dynamically generated for each class)
PENALTY_WEIGHT = 10  # Weight for penalizing incorrect predictions after 50% accuracy
SAVE_PATH = './saved_models/'  # Directory to save model checkpoints
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)

# Temperature scaling class
class TemperatureScaling(nn.Module):
    def __init__(self, init_temp=1.5):
        super(TemperatureScaling, self).__init__()
        self.temperature = nn.Parameter(torch.ones(1) * init_temp)

    def forward(self, logits):
        return logits / self.temperature

# Focal Loss for handling imbalanced datasets
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, outputs, targets):
        BCE_loss = F.cross_entropy(outputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)  # Get the probability
        focal_loss = self.alpha * (1-pt)**self.gamma * BCE_loss
        return focal_loss.mean()

# Custom Loss Function with Focal Loss and Penalty for Wrong Predictions after 50% Accuracy
def custom_loss_function(outputs, targets, current_accuracy):
    # Apply softmax to get probabilities
    probabilities = F.softmax(outputs, dim=1)
    
    # Get the max probability (confidence) and corresponding predicted class
    confidences, predicted_classes = torch.max(probabilities, dim=1)
    
    # Calculate the Focal Loss for class imbalance
    focal_loss = FocalLoss()(outputs, targets)
    
    # Heavily penalize wrong argmax predictions if training accuracy > 50%
    wrong_predictions = (predicted_classes != targets).float()
    if current_accuracy > 0.5:
        wrong_prediction_penalty = PENALTY_WEIGHT * wrong_predictions.sum()
    else:
        wrong_prediction_penalty = 0

    # Calculate the total loss
    total_loss = focal_loss + wrong_prediction_penalty
    return total_loss

# WideResNeXt Block
class WideResNeXtBlock(nn.Module):
    expansion = 2  # Expansion factor for WideResNeXt

    def __init__(self, in_planes, planes, stride=1, cardinality=32, widen_factor=2):
        super(WideResNeXtBlock, self).__init__()
        D = cardinality * widen_factor
        self.conv1 = nn.Conv2d(in_planes, D, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(D)
        self.conv2 = nn.Conv2d(D, D, kernel_size=3, stride=stride, padding=1, groups=cardinality, bias=False)
        self.bn2 = nn.BatchNorm2d(D)
        self.conv3 = nn.Conv2d(D, planes * WideResNeXtBlock.expansion, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes * WideResNeXtBlock.expansion)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes * WideResNeXtBlock.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * WideResNeXtBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * WideResNeXtBlock.expansion)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = torch.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

# WideResNeXt Model
class WideResNeXt(nn.Module):
    def __init__(self, block, num_blocks, cardinality=32, widen_factor=2, num_classes=100):
        super(WideResNeXt, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)

        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1, cardinality=cardinality, widen_factor=widen_factor)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2, cardinality=cardinality, widen_factor=widen_factor)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2, cardinality=cardinality, widen_factor=widen_factor)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2, cardinality=cardinality, widen_factor=widen_factor)

        self.linear = nn.Linear(512 * WideResNeXtBlock.expansion, num_classes)
        self.temperature_scaling = TemperatureScaling()  # Add temperature scaling

    def _make_layer(self, block, planes, num_blocks, stride, cardinality, widen_factor):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride, cardinality, widen_factor))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = torch.nn.functional.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        out = self.temperature_scaling(out)  # Apply temperature scaling to logits
        return out

# WideResNeXt-101 Model Definition
def WideResNeXt101():
    return WideResNeXt(WideResNeXtBlock, [3, 4, 23, 3], cardinality=32, widen_factor=2)

# Custom Dataset class for loading CIFAR100 data from .pkl files
class CIFAR100Dataset(Dataset):
    def __init__(self, file_path):
        with open(file_path, 'rb') as f:
            self.data = pickle.load(f)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image, label = self.data[idx]
        return image, label

# Training function with temperature scaling
def train_with_penalty(epoch, class_thresholds):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        
        # Calculate the overall training accuracy before updating weights
        probabilities = F.softmax(outputs, dim=1)
        _, predicted_classes = torch.max(probabilities, dim=1)
        correct_predictions = predicted_classes.eq(targets).sum().item()
        total += targets.size(0)
        current_accuracy = correct_predictions / total
        
        # Calculate custom loss with penalties if training accuracy is above 50%
        loss = custom_loss_function(outputs, targets, current_accuracy)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        correct += correct_predictions

        if batch_idx % 100 == 0:
            print(f'Epoch {epoch}, Batch {batch_idx}, Loss: {train_loss / (batch_idx + 1):.3f}, Acc: {100.*correct/total:.3f}%')


# Test function with class-specific thresholds and evaluation
def test_with_class_thresholds(epoch, class_thresholds, test_info_path):
    global best_accuracy
    model.eval()
    correct = 0
    total = 0
    high_conf_correct = 0
    high_conf_total = 0
    
    predictions = []  # Store predictions for submission
    ids = []  # Store corresponding IDs for submission
    
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            probabilities = F.softmax(outputs, dim=1)
            confidences, predicted_classes = torch.max(probabilities, dim=1)
            
            # Count correct predictions
            correct_predictions = predicted_classes.eq(targets).sum().item()
            correct += correct_predictions
            total += targets.size(0)
            
            # Class-specific thresholds: Store -1 if confidence is below class-specific threshold
            for i in range(len(inputs)):
                class_idx = predicted_classes[i].item()
                confidence = confidences[i].item()  # Convert to a float for comparison
                
                if confidence >= class_thresholds[class_idx]:  # Use >= to ensure classes at threshold are included
                    predictions.append(class_idx)  # Save the predicted class
                else:
                    predictions.append(-1)  # Assign -1 for low-confidence predictions
                
                ids.append(batch_idx * testloader.batch_size + i)  # Ensure the ID is calculated correctly

    # Save predictions to CSV
    save_predictions_to_csv(ids, predictions)
    
    # Evaluate using calculate_score
    evaluate_and_print_score(test_info_path, 'submission.csv')

    # Calculate accuracy
    test_accuracy = 100. * correct / total
    print(f"Test Accuracy: {test_accuracy:.2f}%")

# Function to save predictions to CSV in correct format
def save_predictions_to_csv(ids, predictions):
    df = pd.DataFrame({'ID': ids, 'Predicted_label': predictions})
    df.to_csv('submission.csv', index=False)
    print("Predictions saved to submission.csv")



# Function to evaluate and print score for each epoch
def evaluate_and_print_score(test_info_path, prediction_file):
    batch_1, batch_2 = evaluate_in_two_sets(test_info_path, prediction_file)
    
    # Print scores for both sets
    print(f"\nBatch 1: Correct: {batch_1['correct']}, Incorrect: {batch_1['incorrect']}, Skipped: {batch_1['skipped']}, Score: {batch_1['score']:.2f}")
    print(f"Batch 2: Correct: {batch_2['correct']}, Incorrect: {batch_2['incorrect']}, Skipped: {batch_2['skipped']}, Score: {batch_2['score']:.2f}")

# Function to calculate the score for predictions
# Function to calculate the score for predictions
def calculate_score(true_labels: pd.Series, predicted_labels: pd.Series, accuracy_threshold: float = 0.7, gamma: float = 5.0):
    data = pd.DataFrame({'True_label': true_labels, 'Predicted_label': predicted_labels})
    
    # Count skipped predictions where Predicted_label is -1
    total_skipped = (data['Predicted_label'] == -1).sum()

    # Filter out skipped predictions for further accuracy calculations
    filtered_df = data[data['Predicted_label'] != -1]
    
    all_classes = list(range(100))  # Assuming CIFAR-100 dataset with 100 classes
    sum_of_correctly_classified_high_accuracy = 0
    sum_of_correctly_classified_low_accuracy = 0
    total_correct = 0
    total_incorrect = 0
    
    accuracy_per_class = {}
    grouped = filtered_df.groupby('Predicted_label')
    
    for name, group in grouped:
        accuracy = (group['True_label'] == group['Predicted_label']).sum() / len(group)
        accuracy_per_class[name] = accuracy
        total_correct += (group['True_label'] == group['Predicted_label']).sum()
        total_incorrect += (group['True_label'] != group['Predicted_label']).sum()
    
    for cls in all_classes:
        total = len(filtered_df[filtered_df['Predicted_label'] == cls])
        class_accuracy = accuracy_per_class.get(cls, 0.0)
        
        if class_accuracy >= accuracy_threshold:
            sum_of_correctly_classified_high_accuracy += total
        else:
            sum_of_correctly_classified_low_accuracy += total

    final_score = sum_of_correctly_classified_high_accuracy - gamma * sum_of_correctly_classified_low_accuracy
    return final_score, total_correct, total_incorrect, total_skipped


# Function to evaluate the test predictions in two sets
def evaluate_in_two_sets(test_info_path: str, prediction_file: str):
    test_info = pd.read_csv(test_info_path)
    predictions = pd.read_csv(prediction_file)
    merged_data = pd.merge(test_info, predictions, on='ID')
    
    first_half = merged_data[:10000]
    second_half = merged_data[10000:20000]
    
    score_first_half, correct_first_half, incorrect_first_half, skipped_first_half = calculate_score(first_half['True_label'], first_half['Predicted_label'])
    score_second_half, correct_second_half, incorrect_second_half, skipped_second_half = calculate_score(second_half['True_label'], second_half['Predicted_label'])
    
    batch_1 = {
        'total': 10000,
        'correct': correct_first_half,
        'incorrect': incorrect_first_half,
        'skipped': skipped_first_half,
        'score': score_first_half
    }
    
    batch_2 = {
        'total': 10000,
        'correct': correct_second_half,
        'incorrect': incorrect_second_half,
        'skipped': skipped_second_half,
        'score': score_second_half
    }
    
    return batch_1, batch_2

# Generate class-specific thresholds
def generate_class_thresholds(trainloader, target_accuracy=99.99):
    class_confidences = {i: [] for i in range(100)}  # Store confidences per class

    model.eval()
    with torch.no_grad():
        for inputs, targets in trainloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            probabilities = F.softmax(outputs, dim=1)
            confidences, predicted_classes = torch.max(probabilities, dim=1)
            
            for i in range(len(targets)):
                class_idx = targets[i].item()
                class_confidences[class_idx].append(confidences[i].item())

    class_thresholds = {}
    for cls, confidences in class_confidences.items():
        sorted_confidences = sorted(confidences)
        threshold_idx = int(len(sorted_confidences) * (1 - target_accuracy / 100))
        class_thresholds[cls] = sorted_confidences[threshold_idx]
    
    return class_thresholds

# Load datasets
train_dataset = CIFAR100Dataset('train.pkl')
test_dataset = CIFAR100Dataset('test.pkl')

trainloader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
testloader = DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=2)

# Model, loss, optimizer, and scheduler
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = WideResNeXt101().to(device)

optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)

best_accuracy = 0.0

# Generate class-specific thresholds based on 99.99% accuracy
class_thresholds = generate_class_thresholds(trainloader, target_accuracy=80)

# Example Training Loop
for epoch in range(0, 100):
    train_with_penalty(epoch, class_thresholds)
    test_with_class_thresholds(epoch, class_thresholds, 'test_info.csv')
    scheduler.step()
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Epoch 0, Batch 0, Loss: 4.581, Acc: 2.344%
# Epoch 0, Batch 100, Loss: 4.522, Acc: 1.825%
# Epoch 0, Batch 200, Loss: 4.329, Acc: 2.791%
# Epoch 0, Batch 300, Loss: 4.164, Acc: 4.036%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 767, Incorrect: 9233, Skipped: 0, Score: -50000.00
# Batch 2: Correct: 740, Incorrect: 9260, Skipped: 0, Score: -50000.00
# Test Accuracy: 0.01%
# Epoch 1, Batch 0, Loss: 3.536, Acc: 10.156%
# Epoch 1, Batch 100, Loss: 3.617, Acc: 9.251%
# Epoch 1, Batch 200, Loss: 3.526, Acc: 10.599%
# Epoch 1, Batch 300, Loss: 3.449, Acc: 11.786%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 1386, Incorrect: 8614, Skipped: 0, Score: -49856.00
# Batch 2: Correct: 1428, Incorrect: 8572, Skipped: 0, Score: -49604.00
# Test Accuracy: 0.01%
# Epoch 2, Batch 0, Loss: 3.205, Acc: 12.500%
# Epoch 2, Batch 100, Loss: 3.073, Acc: 17.814%
# Epoch 2, Batch 200, Loss: 3.032, Acc: 18.315%
# Epoch 2, Batch 300, Loss: 2.979, Acc: 19.295%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 2006, Incorrect: 7994, Skipped: 0, Score: -49310.00
# Batch 2: Correct: 2041, Incorrect: 7959, Skipped: 0, Score: -48734.00
# Test Accuracy: 0.00%
# Epoch 3, Batch 0, Loss: 2.596, Acc: 26.562%
# Epoch 3, Batch 100, Loss: 2.670, Acc: 24.482%
# Epoch 3, Batch 200, Loss: 2.648, Acc: 24.961%
# Epoch 3, Batch 300, Loss: 2.617, Acc: 25.646%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 2319, Incorrect: 7681, Skipped: 0, Score: -49814.00
# Batch 2: Correct: 2403, Incorrect: 7597, Skipped: 0, Score: -49430.00
# Test Accuracy: 0.01%
# Epoch 4, Batch 0, Loss: 2.510, Acc: 25.781%
# Epoch 4, Batch 100, Loss: 2.328, Acc: 30.562%
# Epoch 4, Batch 200, Loss: 2.334, Acc: 30.333%
# Epoch 4, Batch 300, Loss: 2.302, Acc: 30.983%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 2845, Incorrect: 7155, Skipped: 0, Score: -48794.00
# Batch 2: Correct: 2951, Incorrect: 7049, Skipped: 0, Score: -48908.00
# Test Accuracy: 0.01%
# Epoch 5, Batch 0, Loss: 2.188, Acc: 29.688%
# Epoch 5, Batch 100, Loss: 2.033, Acc: 36.626%
# Epoch 5, Batch 200, Loss: 2.040, Acc: 36.194%
# Epoch 5, Batch 300, Loss: 2.018, Acc: 36.742%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 3236, Incorrect: 6764, Skipped: 0, Score: -47384.00
# Batch 2: Correct: 3305, Incorrect: 6695, Skipped: 0, Score: -46928.00
# Test Accuracy: 0.01%
# Epoch 6, Batch 0, Loss: 1.668, Acc: 39.062%
# Epoch 6, Batch 100, Loss: 1.820, Acc: 40.207%
# Epoch 6, Batch 200, Loss: 1.819, Acc: 40.442%
# Epoch 6, Batch 300, Loss: 1.819, Acc: 40.500%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 3714, Incorrect: 6286, Skipped: 0, Score: -46130.00
# Batch 2: Correct: 3738, Incorrect: 6262, Skipped: 0, Score: -46298.00
# Test Accuracy: 0.01%
# Epoch 7, Batch 0, Loss: 1.463, Acc: 42.188%
# Epoch 7, Batch 100, Loss: 1.585, Acc: 46.132%
# Epoch 7, Batch 200, Loss: 1.615, Acc: 45.227%
# Epoch 7, Batch 300, Loss: 1.620, Acc: 45.196%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 3890, Incorrect: 6110, Skipped: 0, Score: -46946.00
# Batch 2: Correct: 4030, Incorrect: 5970, Skipped: 0, Score: -45764.00
# Test Accuracy: 0.01%
# Epoch 8, Batch 0, Loss: 1.283, Acc: 50.000%
# Epoch 8, Batch 100, Loss: 1.422, Acc: 49.745%
# Epoch 8, Batch 200, Loss: 1.449, Acc: 49.141%
# Epoch 8, Batch 300, Loss: 1.475, Acc: 48.663%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4201, Incorrect: 5799, Skipped: 0, Score: -44750.00
# Batch 2: Correct: 4241, Incorrect: 5759, Skipped: 0, Score: -44774.00
# Test Accuracy: 0.01%
# Epoch 9, Batch 0, Loss: 541.186, Acc: 57.812%
# Epoch 9, Batch 100, Loss: 6.649, Acc: 52.344%
# Epoch 9, Batch 200, Loss: 4.032, Acc: 51.391%
# Epoch 9, Batch 300, Loss: 3.159, Acc: 50.984%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4074, Incorrect: 5926, Skipped: 0, Score: -45608.00
# Batch 2: Correct: 4114, Incorrect: 5886, Skipped: 0, Score: -43688.00
# Test Accuracy: 0.00%
# Epoch 10, Batch 0, Loss: 1.352, Acc: 48.438%
# Epoch 10, Batch 100, Loss: 1.202, Acc: 55.453%
# Epoch 10, Batch 200, Loss: 1.245, Acc: 54.155%
# Epoch 10, Batch 300, Loss: 1.271, Acc: 53.763%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4540, Incorrect: 5460, Skipped: 0, Score: -42506.00
# Batch 2: Correct: 4543, Incorrect: 5457, Skipped: 0, Score: -41690.00
# Test Accuracy: 0.01%
# Epoch 11, Batch 0, Loss: 440.808, Acc: 65.625%
# Epoch 11, Batch 100, Loss: 5.461, Acc: 56.931%
# Epoch 11, Batch 200, Loss: 3.350, Acc: 56.083%
# Epoch 11, Batch 300, Loss: 2.655, Acc: 55.471%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4274, Incorrect: 5726, Skipped: 0, Score: -44126.00
# Batch 2: Correct: 4365, Incorrect: 5635, Skipped: 0, Score: -44060.00
# Test Accuracy: 0.01%
# Epoch 12, Batch 0, Loss: 591.138, Acc: 53.906%
# Epoch 12, Batch 100, Loss: 6.933, Acc: 58.284%
# Epoch 12, Batch 200, Loss: 4.055, Acc: 57.447%
# Epoch 12, Batch 300, Loss: 3.101, Acc: 56.982%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4448, Incorrect: 5552, Skipped: 0, Score: -42650.00
# Batch 2: Correct: 4455, Incorrect: 5545, Skipped: 0, Score: -41030.00
# Test Accuracy: 0.00%
# Epoch 13, Batch 0, Loss: 551.047, Acc: 57.031%
# Epoch 13, Batch 100, Loss: 6.424, Acc: 61.193%
# Epoch 13, Batch 200, Loss: 3.782, Acc: 59.441%
# Epoch 13, Batch 300, Loss: 2.906, Acc: 58.531%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4444, Incorrect: 5556, Skipped: 0, Score: -43532.00
# Batch 2: Correct: 4443, Incorrect: 5557, Skipped: 0, Score: -42650.00
# Test Accuracy: 0.00%
# Epoch 14, Batch 0, Loss: 490.983, Acc: 61.719%
# Epoch 14, Batch 100, Loss: 5.809, Acc: 61.610%
# Epoch 14, Batch 200, Loss: 3.444, Acc: 60.467%
# Epoch 14, Batch 300, Loss: 2.668, Acc: 59.624%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4343, Incorrect: 5657, Skipped: 0, Score: -39896.00
# Batch 2: Correct: 4355, Incorrect: 5645, Skipped: 0, Score: -41204.00
# Test Accuracy: 0.01%
# Epoch 15, Batch 0, Loss: 350.703, Acc: 72.656%
# Epoch 15, Batch 100, Loss: 4.376, Acc: 62.933%
# Epoch 15, Batch 200, Loss: 2.699, Acc: 61.727%
# Epoch 15, Batch 300, Loss: 2.145, Acc: 61.161%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4798, Incorrect: 5202, Skipped: 0, Score: -42794.00
# Batch 2: Correct: 4950, Incorrect: 5050, Skipped: 0, Score: -41618.00
# Test Accuracy: 0.01%
# Epoch 16, Batch 0, Loss: 440.769, Acc: 65.625%
# Epoch 16, Batch 100, Loss: 5.266, Acc: 64.295%
# Epoch 16, Batch 200, Loss: 3.132, Acc: 62.613%
# Epoch 16, Batch 300, Loss: 2.424, Acc: 62.012%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4687, Incorrect: 5313, Skipped: 0, Score: -42764.00
# Batch 2: Correct: 4785, Incorrect: 5215, Skipped: 0, Score: -40112.00
# Test Accuracy: 0.01%
# Epoch 17, Batch 0, Loss: 390.778, Acc: 69.531%
# Epoch 17, Batch 100, Loss: 4.692, Acc: 65.919%
# Epoch 17, Batch 200, Loss: 3.031, Acc: 62.539%
# Epoch 17, Batch 300, Loss: 3.290, Acc: 51.069%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 3193, Incorrect: 6807, Skipped: 0, Score: -46430.00
# Batch 2: Correct: 3240, Incorrect: 6760, Skipped: 0, Score: -46262.00
# Test Accuracy: 0.01%
# Epoch 18, Batch 0, Loss: 2.823, Acc: 32.812%
# Epoch 18, Batch 100, Loss: 1.613, Acc: 49.636%
# Epoch 18, Batch 200, Loss: 1.356, Acc: 53.269%
# Epoch 18, Batch 300, Loss: 1.273, Acc: 54.760%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4499, Incorrect: 5501, Skipped: 0, Score: -43364.00
# Batch 2: Correct: 4608, Incorrect: 5392, Skipped: 0, Score: -42392.00
# Test Accuracy: 0.01%
# Epoch 19, Batch 0, Loss: 460.915, Acc: 64.062%
# Epoch 19, Batch 100, Loss: 5.478, Acc: 62.454%
# Epoch 19, Batch 200, Loss: 3.245, Acc: 61.482%
# Epoch 19, Batch 300, Loss: 2.510, Acc: 60.727%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 5031, Incorrect: 4969, Skipped: 0, Score: -42134.00
# Batch 2: Correct: 5013, Incorrect: 4987, Skipped: 0, Score: -42416.00
# Test Accuracy: 0.01%
# Epoch 20, Batch 0, Loss: 320.598, Acc: 75.000%
# Epoch 20, Batch 100, Loss: 3.975, Acc: 65.633%
# Epoch 20, Batch 200, Loss: 2.454, Acc: 64.016%
# Epoch 20, Batch 300, Loss: 1.949, Acc: 63.471%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4746, Incorrect: 5254, Skipped: 0, Score: -40286.00
# Batch 2: Correct: 4847, Incorrect: 5153, Skipped: 0, Score: -38774.00
# Test Accuracy: 0.01%
# Epoch 21, Batch 0, Loss: 370.737, Acc: 71.094%
# Epoch 21, Batch 100, Loss: 4.438, Acc: 66.839%
# Epoch 21, Batch 200, Loss: 2.680, Acc: 64.980%
# Epoch 21, Batch 300, Loss: 2.114, Acc: 63.772%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4606, Incorrect: 5394, Skipped: 0, Score: -41486.00
# Batch 2: Correct: 4714, Incorrect: 5286, Skipped: 0, Score: -40508.00
# Test Accuracy: 0.01%
# Epoch 22, Batch 0, Loss: 480.941, Acc: 62.500%
# Epoch 22, Batch 100, Loss: 5.565, Acc: 66.917%
# Epoch 22, Batch 200, Loss: 3.222, Acc: 65.609%
# Epoch 22, Batch 300, Loss: 2.471, Acc: 64.374%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4419, Incorrect: 5581, Skipped: 0, Score: -42506.00
# Batch 2: Correct: 4462, Incorrect: 5538, Skipped: 0, Score: -42992.00
# Test Accuracy: 0.01%
# Epoch 23, Batch 0, Loss: 450.788, Acc: 64.844%
# Epoch 23, Batch 100, Loss: 5.194, Acc: 68.456%
# Epoch 23, Batch 200, Loss: 3.016, Acc: 67.366%
# Epoch 23, Batch 300, Loss: 2.328, Acc: 65.690%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 5000, Incorrect: 5000, Skipped: 0, Score: -40592.00
# Batch 2: Correct: 5001, Incorrect: 4999, Skipped: 0, Score: -39680.00
# Test Accuracy: 0.01%
# Epoch 24, Batch 0, Loss: 360.742, Acc: 71.875%
# Epoch 24, Batch 100, Loss: 4.309, Acc: 68.123%
# Epoch 24, Batch 200, Loss: 2.581, Acc: 66.795%
# Epoch 24, Batch 300, Loss: 2.010, Acc: 66.147%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4828, Incorrect: 5172, Skipped: 0, Score: -40844.00
# Batch 2: Correct: 4923, Incorrect: 5077, Skipped: 0, Score: -39482.00
# Test Accuracy: 0.01%
# Epoch 25, Batch 0, Loss: 410.677, Acc: 67.969%
# Epoch 25, Batch 100, Loss: 4.773, Acc: 69.346%
# Epoch 25, Batch 200, Loss: 2.789, Acc: 67.953%
# Epoch 25, Batch 300, Loss: 2.170, Acc: 66.593%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4792, Incorrect: 5208, Skipped: 0, Score: -39374.00
# Batch 2: Correct: 4798, Incorrect: 5202, Skipped: 0, Score: -41726.00
# Test Accuracy: 0.01%
# Epoch 26, Batch 0, Loss: 360.719, Acc: 71.875%
# Epoch 26, Batch 100, Loss: 4.260, Acc: 69.717%
# Epoch 26, Batch 200, Loss: 2.551, Acc: 67.953%
# Epoch 26, Batch 300, Loss: 1.980, Acc: 67.073%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4819, Incorrect: 5181, Skipped: 0, Score: -38978.00
# Batch 2: Correct: 4868, Incorrect: 5132, Skipped: 0, Score: -37628.00
# Test Accuracy: 0.01%
# Epoch 27, Batch 0, Loss: 330.603, Acc: 74.219%
# Epoch 27, Batch 100, Loss: 3.937, Acc: 70.490%
# Epoch 27, Batch 200, Loss: 2.356, Acc: 68.964%
# Epoch 27, Batch 300, Loss: 1.840, Acc: 68.145%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4578, Incorrect: 5422, Skipped: 0, Score: -38480.00
# Batch 2: Correct: 4676, Incorrect: 5324, Skipped: 0, Score: -36686.00
# Test Accuracy: 0.00%
# Epoch 28, Batch 0, Loss: 330.522, Acc: 74.219%
# Epoch 28, Batch 100, Loss: 4.004, Acc: 70.065%
# Epoch 28, Batch 200, Loss: 2.388, Acc: 68.968%
# Epoch 28, Batch 300, Loss: 1.862, Acc: 68.026%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 4753, Incorrect: 5247, Skipped: 0, Score: -39542.00
# Batch 2: Correct: 4810, Incorrect: 5190, Skipped: 0, Score: -39320.00
# Test Accuracy: 0.01%
# Epoch 29, Batch 0, Loss: 410.867, Acc: 67.969%
# Epoch 29, Batch 100, Loss: 4.685, Acc: 71.682%
# Epoch 29, Batch 200, Loss: 2.717, Acc: 69.994%
# Epoch 29, Batch 300, Loss: 2.076, Acc: 68.794%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 3040, Incorrect: 6960, Skipped: 0, Score: -43544.00
# Batch 2: Correct: 3113, Incorrect: 6887, Skipped: 0, Score: -44108.00
# Test Accuracy: 0.01%
# Epoch 30, Batch 0, Loss: 3.559, Acc: 49.219%
# Epoch 30, Batch 100, Loss: 2.570, Acc: 55.732%
# Epoch 30, Batch 200, Loss: 1.473, Acc: 68.447%
# Epoch 30, Batch 300, Loss: 1.071, Acc: 74.180%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6260, Incorrect: 3740, Skipped: 0, Score: -27860.00
# Batch 2: Correct: 6339, Incorrect: 3661, Skipped: 0, Score: -29894.00
# Test Accuracy: 0.01%
# Epoch 31, Batch 0, Loss: 110.112, Acc: 91.406%
# Epoch 31, Batch 100, Loss: 1.237, Acc: 91.337%
# Epoch 31, Batch 200, Loss: 0.688, Acc: 91.558%
# Epoch 31, Batch 300, Loss: 0.504, Acc: 91.671%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6327, Incorrect: 3673, Skipped: 0, Score: -28178.00
# Batch 2: Correct: 6410, Incorrect: 3590, Skipped: 0, Score: -27950.00
# Test Accuracy: 0.01%
# Epoch 32, Batch 0, Loss: 50.052, Acc: 96.094%
# Epoch 32, Batch 100, Loss: 0.551, Acc: 95.792%
# Epoch 32, Batch 200, Loss: 0.308, Acc: 95.732%
# Epoch 32, Batch 300, Loss: 0.224, Acc: 95.793%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6301, Incorrect: 3699, Skipped: 0, Score: -30632.00
# Batch 2: Correct: 6354, Incorrect: 3646, Skipped: 0, Score: -26522.00
# Test Accuracy: 0.01%
# Epoch 33, Batch 0, Loss: 20.017, Acc: 98.438%
# Epoch 33, Batch 100, Loss: 0.224, Acc: 97.772%
# Epoch 33, Batch 200, Loss: 0.126, Acc: 97.699%
# Epoch 33, Batch 300, Loss: 0.094, Acc: 97.659%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6321, Incorrect: 3679, Skipped: 0, Score: -29744.00
# Batch 2: Correct: 6372, Incorrect: 3628, Skipped: 0, Score: -27734.00
# Test Accuracy: 0.01%
# Epoch 34, Batch 0, Loss: 20.020, Acc: 98.438%
# Epoch 34, Batch 100, Loss: 0.212, Acc: 98.700%
# Epoch 34, Batch 200, Loss: 0.115, Acc: 98.620%
# Epoch 34, Batch 300, Loss: 0.082, Acc: 98.588%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6337, Incorrect: 3663, Skipped: 0, Score: -28052.00
# Batch 2: Correct: 6364, Incorrect: 3636, Skipped: 0, Score: -29558.00
# Test Accuracy: 0.01%
# Epoch 35, Batch 0, Loss: 10.014, Acc: 99.219%
# Epoch 35, Batch 100, Loss: 0.111, Acc: 99.072%
# Epoch 35, Batch 200, Loss: 0.061, Acc: 99.028%
# Epoch 35, Batch 300, Loss: 0.045, Acc: 98.944%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6275, Incorrect: 3725, Skipped: 0, Score: -28340.00
# Batch 2: Correct: 6322, Incorrect: 3678, Skipped: 0, Score: -27830.00
# Test Accuracy: 0.01%
# Epoch 36, Batch 0, Loss: 10.009, Acc: 99.219%
# Epoch 36, Batch 100, Loss: 0.112, Acc: 99.033%
# Epoch 36, Batch 200, Loss: 0.063, Acc: 98.830%
# Epoch 36, Batch 300, Loss: 0.046, Acc: 98.827%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6266, Incorrect: 3734, Skipped: 0, Score: -29462.00
# Batch 2: Correct: 6343, Incorrect: 3657, Skipped: 0, Score: -28664.00
# Test Accuracy: 0.01%
# Epoch 37, Batch 0, Loss: 10.016, Acc: 99.219%
# Epoch 37, Batch 100, Loss: 0.106, Acc: 99.335%
# Epoch 37, Batch 200, Loss: 0.057, Acc: 99.285%
# Epoch 37, Batch 300, Loss: 0.042, Acc: 99.169%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6238, Incorrect: 3762, Skipped: 0, Score: -28328.00
# Batch 2: Correct: 6328, Incorrect: 3672, Skipped: 0, Score: -27314.00
# Test Accuracy: 0.01%
# Epoch 38, Batch 0, Loss: 40.014, Acc: 96.875%
# Epoch 38, Batch 100, Loss: 0.405, Acc: 99.165%
# Epoch 38, Batch 200, Loss: 0.208, Acc: 99.195%
# Epoch 38, Batch 300, Loss: 0.142, Acc: 99.224%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6275, Incorrect: 3725, Skipped: 0, Score: -29210.00
# Batch 2: Correct: 6329, Incorrect: 3671, Skipped: 0, Score: -30962.00
# Test Accuracy: 0.01%
# Epoch 39, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 39, Batch 100, Loss: 0.008, Acc: 99.420%
# Epoch 39, Batch 200, Loss: 0.008, Acc: 99.386%
# Epoch 39, Batch 300, Loss: 0.008, Acc: 99.364%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6268, Incorrect: 3732, Skipped: 0, Score: -29210.00
# Batch 2: Correct: 6279, Incorrect: 3721, Skipped: 0, Score: -29738.00
# Test Accuracy: 0.01%
# Epoch 40, Batch 0, Loss: 0.002, Acc: 100.000%
# Epoch 40, Batch 100, Loss: 0.006, Acc: 99.459%
# Epoch 40, Batch 200, Loss: 0.007, Acc: 99.339%
# Epoch 40, Batch 300, Loss: 0.008, Acc: 99.312%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6274, Incorrect: 3726, Skipped: 0, Score: -30422.00
# Batch 2: Correct: 6304, Incorrect: 3696, Skipped: 0, Score: -29330.00
# Test Accuracy: 0.01%
# Epoch 41, Batch 0, Loss: 0.001, Acc: 100.000%
# Epoch 41, Batch 100, Loss: 0.009, Acc: 99.435%
# Epoch 41, Batch 200, Loss: 0.008, Acc: 99.359%
# Epoch 41, Batch 300, Loss: 0.009, Acc: 99.336%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6290, Incorrect: 3710, Skipped: 0, Score: -30962.00
# Batch 2: Correct: 6293, Incorrect: 3707, Skipped: 0, Score: -27290.00
# Test Accuracy: 0.01%
# Epoch 42, Batch 0, Loss: 10.005, Acc: 99.219%
# Epoch 42, Batch 100, Loss: 0.105, Acc: 99.373%
# Epoch 42, Batch 200, Loss: 0.056, Acc: 99.436%
# Epoch 42, Batch 300, Loss: 0.040, Acc: 99.393%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6264, Incorrect: 3736, Skipped: 0, Score: -29228.00
# Batch 2: Correct: 6300, Incorrect: 3700, Skipped: 0, Score: -29378.00
# Test Accuracy: 0.01%
# Epoch 43, Batch 0, Loss: 20.012, Acc: 98.438%
# Epoch 43, Batch 100, Loss: 0.203, Acc: 99.513%
# Epoch 43, Batch 200, Loss: 0.106, Acc: 99.417%
# Epoch 43, Batch 300, Loss: 0.074, Acc: 99.356%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6250, Incorrect: 3750, Skipped: 0, Score: -28922.00
# Batch 2: Correct: 6283, Incorrect: 3717, Skipped: 0, Score: -28196.00
# Test Accuracy: 0.01%
# Epoch 44, Batch 0, Loss: 0.001, Acc: 100.000%
# Epoch 44, Batch 100, Loss: 0.006, Acc: 99.551%
# Epoch 44, Batch 200, Loss: 0.008, Acc: 99.316%
# Epoch 44, Batch 300, Loss: 0.010, Acc: 99.221%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6255, Incorrect: 3745, Skipped: 0, Score: -29336.00
# Batch 2: Correct: 6271, Incorrect: 3729, Skipped: 0, Score: -27422.00
# Test Accuracy: 0.01%
# Epoch 45, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 45, Batch 100, Loss: 0.008, Acc: 99.242%
# Epoch 45, Batch 200, Loss: 0.008, Acc: 99.265%
# Epoch 45, Batch 300, Loss: 0.009, Acc: 99.242%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6230, Incorrect: 3770, Skipped: 0, Score: -30344.00
# Batch 2: Correct: 6222, Incorrect: 3778, Skipped: 0, Score: -25796.00
# Test Accuracy: 0.01%
# Epoch 46, Batch 0, Loss: 0.001, Acc: 100.000%
# Epoch 46, Batch 100, Loss: 0.007, Acc: 99.466%
# Epoch 46, Batch 200, Loss: 0.010, Acc: 99.335%
# Epoch 46, Batch 300, Loss: 0.011, Acc: 99.240%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6214, Incorrect: 3786, Skipped: 0, Score: -28634.00
# Batch 2: Correct: 6240, Incorrect: 3760, Skipped: 0, Score: -29198.00
# Test Accuracy: 0.01%
# Epoch 47, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 47, Batch 100, Loss: 0.006, Acc: 99.575%
# Epoch 47, Batch 200, Loss: 0.006, Acc: 99.518%
# Epoch 47, Batch 300, Loss: 0.007, Acc: 99.463%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6223, Incorrect: 3777, Skipped: 0, Score: -31532.00
# Batch 2: Correct: 6215, Incorrect: 3785, Skipped: 0, Score: -30614.00
# Test Accuracy: 0.01%
# Epoch 48, Batch 0, Loss: 0.001, Acc: 100.000%
# Epoch 48, Batch 100, Loss: 0.008, Acc: 99.474%
# Epoch 48, Batch 200, Loss: 0.008, Acc: 99.436%
# Epoch 48, Batch 300, Loss: 0.008, Acc: 99.398%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6202, Incorrect: 3798, Skipped: 0, Score: -30284.00
# Batch 2: Correct: 6255, Incorrect: 3745, Skipped: 0, Score: -27632.00
# Test Accuracy: 0.01%
# Epoch 49, Batch 0, Loss: 10.005, Acc: 99.219%
# Epoch 49, Batch 100, Loss: 0.108, Acc: 99.435%
# Epoch 49, Batch 200, Loss: 0.059, Acc: 99.363%
# Epoch 49, Batch 300, Loss: 0.042, Acc: 99.315%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6257, Incorrect: 3743, Skipped: 0, Score: -29096.00
# Batch 2: Correct: 6262, Incorrect: 3738, Skipped: 0, Score: -28082.00
# Test Accuracy: 0.01%
# Epoch 50, Batch 0, Loss: 0.002, Acc: 100.000%
# Epoch 50, Batch 100, Loss: 0.006, Acc: 99.358%
# Epoch 50, Batch 200, Loss: 0.006, Acc: 99.339%
# Epoch 50, Batch 300, Loss: 0.007, Acc: 99.317%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6178, Incorrect: 3822, Skipped: 0, Score: -31130.00
# Batch 2: Correct: 6231, Incorrect: 3769, Skipped: 0, Score: -30380.00
# Test Accuracy: 0.01%
# Epoch 51, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 51, Batch 100, Loss: 0.009, Acc: 99.141%
# Epoch 51, Batch 200, Loss: 0.010, Acc: 99.122%
# Epoch 51, Batch 300, Loss: 0.010, Acc: 99.128%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6208, Incorrect: 3792, Skipped: 0, Score: -29750.00
# Batch 2: Correct: 6203, Incorrect: 3797, Skipped: 0, Score: -31676.00
# Test Accuracy: 0.01%
# Epoch 52, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 52, Batch 100, Loss: 0.007, Acc: 99.343%
# Epoch 52, Batch 200, Loss: 0.009, Acc: 99.296%
# Epoch 52, Batch 300, Loss: 0.009, Acc: 99.211%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6172, Incorrect: 3828, Skipped: 0, Score: -32444.00
# Batch 2: Correct: 6200, Incorrect: 3800, Skipped: 0, Score: -32948.00
# Test Accuracy: 0.01%
# Epoch 53, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 53, Batch 100, Loss: 0.008, Acc: 99.296%
# Epoch 53, Batch 200, Loss: 0.009, Acc: 99.242%
# Epoch 53, Batch 300, Loss: 0.010, Acc: 99.143%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6185, Incorrect: 3815, Skipped: 0, Score: -31286.00
# Batch 2: Correct: 6177, Incorrect: 3823, Skipped: 0, Score: -32168.00
# Test Accuracy: 0.01%
# Epoch 54, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 54, Batch 100, Loss: 0.010, Acc: 99.196%
# Epoch 54, Batch 200, Loss: 0.011, Acc: 99.145%
# Epoch 54, Batch 300, Loss: 0.013, Acc: 98.980%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6203, Incorrect: 3797, Skipped: 0, Score: -30482.00
# Batch 2: Correct: 6206, Incorrect: 3794, Skipped: 0, Score: -31010.00
# Test Accuracy: 0.01%
# Epoch 55, Batch 0, Loss: 10.002, Acc: 99.219%
# Epoch 55, Batch 100, Loss: 0.110, Acc: 99.242%
# Epoch 55, Batch 200, Loss: 0.060, Acc: 99.160%
# Epoch 55, Batch 300, Loss: 0.043, Acc: 99.149%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6165, Incorrect: 3835, Skipped: 0, Score: -30146.00
# Batch 2: Correct: 6200, Incorrect: 3800, Skipped: 0, Score: -26528.00
# Test Accuracy: 0.01%
# Epoch 56, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 56, Batch 100, Loss: 0.009, Acc: 99.257%
# Epoch 56, Batch 200, Loss: 0.009, Acc: 99.227%
# Epoch 56, Batch 300, Loss: 0.011, Acc: 99.112%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6123, Incorrect: 3877, Skipped: 0, Score: -30950.00
# Batch 2: Correct: 6148, Incorrect: 3852, Skipped: 0, Score: -28928.00
# Test Accuracy: 0.01%
# Epoch 57, Batch 0, Loss: 30.023, Acc: 97.656%
# Epoch 57, Batch 100, Loss: 0.311, Acc: 99.018%
# Epoch 57, Batch 200, Loss: 0.166, Acc: 98.799%
# Epoch 57, Batch 300, Loss: 0.117, Acc: 98.783%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6120, Incorrect: 3880, Skipped: 0, Score: -32168.00
# Batch 2: Correct: 6150, Incorrect: 3850, Skipped: 0, Score: -31862.00
# Test Accuracy: 0.01%
# Epoch 58, Batch 0, Loss: 0.003, Acc: 100.000%
# Epoch 58, Batch 100, Loss: 0.012, Acc: 99.095%
# Epoch 58, Batch 200, Loss: 0.015, Acc: 98.978%
# Epoch 58, Batch 300, Loss: 0.015, Acc: 98.936%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6137, Incorrect: 3863, Skipped: 0, Score: -28886.00
# Batch 2: Correct: 6165, Incorrect: 3835, Skipped: 0, Score: -28748.00
# Test Accuracy: 0.01%
# Epoch 59, Batch 0, Loss: 0.011, Acc: 100.000%
# Epoch 59, Batch 100, Loss: 0.010, Acc: 99.296%
# Epoch 59, Batch 200, Loss: 0.749, Acc: 95.787%
# Epoch 59, Batch 300, Loss: 0.588, Acc: 94.630%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6123, Incorrect: 3877, Skipped: 0, Score: -29504.00
# Batch 2: Correct: 6211, Incorrect: 3789, Skipped: 0, Score: -29192.00
# Test Accuracy: 0.01%
# Epoch 60, Batch 0, Loss: 10.006, Acc: 99.219%
# Epoch 60, Batch 100, Loss: 0.117, Acc: 98.468%
# Epoch 60, Batch 200, Loss: 0.066, Acc: 98.686%
# Epoch 60, Batch 300, Loss: 0.048, Acc: 98.801%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6307, Incorrect: 3693, Skipped: 0, Score: -30620.00
# Batch 2: Correct: 6354, Incorrect: 3646, Skipped: 0, Score: -28400.00
# Test Accuracy: 0.01%
# Epoch 61, Batch 0, Loss: 0.002, Acc: 100.000%
# Epoch 61, Batch 100, Loss: 0.004, Acc: 99.567%
# Epoch 61, Batch 200, Loss: 0.004, Acc: 99.607%
# Epoch 61, Batch 300, Loss: 0.004, Acc: 99.611%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6313, Incorrect: 3687, Skipped: 0, Score: -28478.00
# Batch 2: Correct: 6376, Incorrect: 3624, Skipped: 0, Score: -28844.00
# Test Accuracy: 0.01%
# Epoch 62, Batch 0, Loss: 10.003, Acc: 99.219%
# Epoch 62, Batch 100, Loss: 0.101, Acc: 99.729%
# Epoch 62, Batch 200, Loss: 0.052, Acc: 99.782%
# Epoch 62, Batch 300, Loss: 0.035, Acc: 99.764%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6306, Incorrect: 3694, Skipped: 0, Score: -28958.00
# Batch 2: Correct: 6357, Incorrect: 3643, Skipped: 0, Score: -27890.00
# Test Accuracy: 0.01%
# Epoch 63, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 63, Batch 100, Loss: 0.002, Acc: 99.838%
# Epoch 63, Batch 200, Loss: 0.002, Acc: 99.841%
# Epoch 63, Batch 300, Loss: 0.002, Acc: 99.852%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6310, Incorrect: 3690, Skipped: 0, Score: -27722.00
# Batch 2: Correct: 6367, Incorrect: 3633, Skipped: 0, Score: -28106.00
# Test Accuracy: 0.01%
# Epoch 64, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 64, Batch 100, Loss: 0.001, Acc: 99.899%
# Epoch 64, Batch 200, Loss: 0.001, Acc: 99.868%
# Epoch 64, Batch 300, Loss: 0.001, Acc: 99.891%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6304, Incorrect: 3696, Skipped: 0, Score: -27170.00
# Batch 2: Correct: 6371, Incorrect: 3629, Skipped: 0, Score: -29516.00
# Test Accuracy: 0.01%
# Epoch 65, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 65, Batch 100, Loss: 0.001, Acc: 99.884%
# Epoch 65, Batch 200, Loss: 0.001, Acc: 99.887%
# Epoch 65, Batch 300, Loss: 0.001, Acc: 99.881%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6314, Incorrect: 3686, Skipped: 0, Score: -28838.00
# Batch 2: Correct: 6391, Incorrect: 3609, Skipped: 0, Score: -27026.00
# Test Accuracy: 0.01%
# Epoch 66, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 66, Batch 100, Loss: 0.002, Acc: 99.830%
# Epoch 66, Batch 200, Loss: 0.001, Acc: 99.876%
# Epoch 66, Batch 300, Loss: 0.001, Acc: 99.883%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6328, Incorrect: 3672, Skipped: 0, Score: -28664.00
# Batch 2: Correct: 6388, Incorrect: 3612, Skipped: 0, Score: -28244.00
# Test Accuracy: 0.01%
# Epoch 67, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 67, Batch 100, Loss: 0.001, Acc: 99.930%
# Epoch 67, Batch 200, Loss: 0.001, Acc: 99.938%
# Epoch 67, Batch 300, Loss: 0.001, Acc: 99.930%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6318, Incorrect: 3682, Skipped: 0, Score: -29642.00
# Batch 2: Correct: 6368, Incorrect: 3632, Skipped: 0, Score: -27476.00
# Test Accuracy: 0.01%
# Epoch 68, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 68, Batch 100, Loss: 0.001, Acc: 99.899%
# Epoch 68, Batch 200, Loss: 0.001, Acc: 99.922%
# Epoch 68, Batch 300, Loss: 0.001, Acc: 99.914%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6331, Incorrect: 3669, Skipped: 0, Score: -29354.00
# Batch 2: Correct: 6386, Incorrect: 3614, Skipped: 0, Score: -26972.00
# Test Accuracy: 0.01%
# Epoch 69, Batch 0, Loss: 0.001, Acc: 100.000%
# Epoch 69, Batch 100, Loss: 0.000, Acc: 99.946%
# Epoch 69, Batch 200, Loss: 0.001, Acc: 99.930%
# Epoch 69, Batch 300, Loss: 0.001, Acc: 99.925%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6331, Incorrect: 3669, Skipped: 0, Score: -29552.00
# Batch 2: Correct: 6401, Incorrect: 3599, Skipped: 0, Score: -27932.00
# Test Accuracy: 0.01%
# Epoch 70, Batch 0, Loss: 0.001, Acc: 100.000%
# Epoch 70, Batch 100, Loss: 0.001, Acc: 99.915%
# Epoch 70, Batch 200, Loss: 0.001, Acc: 99.926%
# Epoch 70, Batch 300, Loss: 0.001, Acc: 99.922%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6326, Incorrect: 3674, Skipped: 0, Score: -30692.00
# Batch 2: Correct: 6376, Incorrect: 3624, Skipped: 0, Score: -27062.00
# Test Accuracy: 0.01%
# Epoch 71, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 71, Batch 100, Loss: 0.001, Acc: 99.915%
# Epoch 71, Batch 200, Loss: 0.001, Acc: 99.911%
# Epoch 71, Batch 300, Loss: 0.001, Acc: 99.914%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6343, Incorrect: 3657, Skipped: 0, Score: -30758.00
# Batch 2: Correct: 6394, Incorrect: 3606, Skipped: 0, Score: -27212.00
# Test Accuracy: 0.01%
# Epoch 72, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 72, Batch 100, Loss: 0.001, Acc: 99.946%
# Epoch 72, Batch 200, Loss: 0.001, Acc: 99.930%
# Epoch 72, Batch 300, Loss: 0.001, Acc: 99.930%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6351, Incorrect: 3649, Skipped: 0, Score: -29144.00
# Batch 2: Correct: 6397, Incorrect: 3603, Skipped: 0, Score: -25970.00
# Test Accuracy: 0.01%
# Epoch 73, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 73, Batch 100, Loss: 0.001, Acc: 99.930%
# Epoch 73, Batch 200, Loss: 0.001, Acc: 99.930%
# Epoch 73, Batch 300, Loss: 0.001, Acc: 99.943%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6337, Incorrect: 3663, Skipped: 0, Score: -29738.00
# Batch 2: Correct: 6383, Incorrect: 3617, Skipped: 0, Score: -29528.00
# Test Accuracy: 0.01%
# Epoch 74, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 74, Batch 100, Loss: 0.000, Acc: 99.946%
# Epoch 74, Batch 200, Loss: 0.001, Acc: 99.946%
# Epoch 74, Batch 300, Loss: 0.001, Acc: 99.940%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6372, Incorrect: 3628, Skipped: 0, Score: -30008.00
# Batch 2: Correct: 6405, Incorrect: 3595, Skipped: 0, Score: -25970.00
# Test Accuracy: 0.01%
# Epoch 75, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 75, Batch 100, Loss: 0.001, Acc: 99.923%
# Epoch 75, Batch 200, Loss: 0.001, Acc: 99.934%
# Epoch 75, Batch 300, Loss: 0.001, Acc: 99.933%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6370, Incorrect: 3630, Skipped: 0, Score: -30032.00
# Batch 2: Correct: 6395, Incorrect: 3605, Skipped: 0, Score: -26336.00
# Test Accuracy: 0.01%
# Epoch 76, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 76, Batch 100, Loss: 0.001, Acc: 99.977%
# Epoch 76, Batch 200, Loss: 0.001, Acc: 99.953%
# Epoch 76, Batch 300, Loss: 0.001, Acc: 99.956%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6351, Incorrect: 3649, Skipped: 0, Score: -30128.00
# Batch 2: Correct: 6389, Incorrect: 3611, Skipped: 0, Score: -27878.00
# Test Accuracy: 0.01%
# Epoch 77, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 77, Batch 100, Loss: 0.001, Acc: 99.930%
# Epoch 77, Batch 200, Loss: 0.000, Acc: 99.946%
# Epoch 77, Batch 300, Loss: 0.000, Acc: 99.958%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6351, Incorrect: 3649, Skipped: 0, Score: -30656.00
# Batch 2: Correct: 6381, Incorrect: 3619, Skipped: 0, Score: -26672.00
# Test Accuracy: 0.01%
# Epoch 78, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 78, Batch 100, Loss: 0.000, Acc: 99.969%
# Epoch 78, Batch 200, Loss: 0.001, Acc: 99.965%
# Epoch 78, Batch 300, Loss: 0.001, Acc: 99.969%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6346, Incorrect: 3654, Skipped: 0, Score: -30086.00
# Batch 2: Correct: 6396, Incorrect: 3604, Skipped: 0, Score: -27794.00
# Test Accuracy: 0.01%
# Epoch 79, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 79, Batch 100, Loss: 0.001, Acc: 99.961%
# Epoch 79, Batch 200, Loss: 0.001, Acc: 99.965%
# Epoch 79, Batch 300, Loss: 0.001, Acc: 99.953%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6350, Incorrect: 3650, Skipped: 0, Score: -30566.00
# Batch 2: Correct: 6417, Incorrect: 3583, Skipped: 0, Score: -27890.00
# Test Accuracy: 0.01%
# Epoch 80, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 80, Batch 100, Loss: 0.000, Acc: 99.977%
# Epoch 80, Batch 200, Loss: 0.000, Acc: 99.973%
# Epoch 80, Batch 300, Loss: 0.000, Acc: 99.964%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6346, Incorrect: 3654, Skipped: 0, Score: -31226.00
# Batch 2: Correct: 6405, Incorrect: 3595, Skipped: 0, Score: -27104.00
# Test Accuracy: 0.01%
# Epoch 81, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 81, Batch 100, Loss: 0.000, Acc: 99.946%
# Epoch 81, Batch 200, Loss: 0.000, Acc: 99.953%
# Epoch 81, Batch 300, Loss: 0.000, Acc: 99.951%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6387, Incorrect: 3613, Skipped: 0, Score: -28892.00
# Batch 2: Correct: 6397, Incorrect: 3603, Skipped: 0, Score: -28850.00
# Test Accuracy: 0.01%
# Epoch 82, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 82, Batch 100, Loss: 0.001, Acc: 99.930%
# Epoch 82, Batch 200, Loss: 0.001, Acc: 99.949%
# Epoch 82, Batch 300, Loss: 0.001, Acc: 99.956%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6359, Incorrect: 3641, Skipped: 0, Score: -28370.00
# Batch 2: Correct: 6381, Incorrect: 3619, Skipped: 0, Score: -26588.00
# Test Accuracy: 0.01%
# Epoch 83, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 83, Batch 100, Loss: 0.000, Acc: 99.992%
# Epoch 83, Batch 200, Loss: 0.000, Acc: 99.977%
# Epoch 83, Batch 300, Loss: 0.000, Acc: 99.974%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6362, Incorrect: 3638, Skipped: 0, Score: -27740.00
# Batch 2: Correct: 6393, Incorrect: 3607, Skipped: 0, Score: -27134.00
# Test Accuracy: 0.01%
# Epoch 84, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 84, Batch 100, Loss: 0.000, Acc: 99.977%
# Epoch 84, Batch 200, Loss: 0.000, Acc: 99.984%
# Epoch 84, Batch 300, Loss: 0.000, Acc: 99.979%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6352, Incorrect: 3648, Skipped: 0, Score: -28982.00
# Batch 2: Correct: 6410, Incorrect: 3590, Skipped: 0, Score: -26312.00
# Test Accuracy: 0.01%
# Epoch 85, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 85, Batch 100, Loss: 0.000, Acc: 99.977%
# Epoch 85, Batch 200, Loss: 0.000, Acc: 99.977%
# Epoch 85, Batch 300, Loss: 0.000, Acc: 99.971%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6350, Incorrect: 3650, Skipped: 0, Score: -29186.00
# Batch 2: Correct: 6421, Incorrect: 3579, Skipped: 0, Score: -27050.00
# Test Accuracy: 0.01%
# Epoch 86, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 86, Batch 100, Loss: 0.000, Acc: 99.977%
# Epoch 86, Batch 200, Loss: 0.000, Acc: 99.965%
# Epoch 86, Batch 300, Loss: 0.000, Acc: 99.971%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6319, Incorrect: 3681, Skipped: 0, Score: -30266.00
# Batch 2: Correct: 6411, Incorrect: 3589, Skipped: 0, Score: -26936.00
# Test Accuracy: 0.01%
# Epoch 87, Batch 0, Loss: 0.001, Acc: 100.000%
# Epoch 87, Batch 100, Loss: 0.000, Acc: 99.961%
# Epoch 87, Batch 200, Loss: 0.000, Acc: 99.961%
# Epoch 87, Batch 300, Loss: 0.000, Acc: 99.956%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6355, Incorrect: 3645, Skipped: 0, Score: -28406.00
# Batch 2: Correct: 6401, Incorrect: 3599, Skipped: 0, Score: -26960.00
# Test Accuracy: 0.01%
# Epoch 88, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 88, Batch 100, Loss: 0.001, Acc: 99.969%
# Epoch 88, Batch 200, Loss: 0.001, Acc: 99.965%
# Epoch 88, Batch 300, Loss: 0.001, Acc: 99.969%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6350, Incorrect: 3650, Skipped: 0, Score: -30650.00
# Batch 2: Correct: 6405, Incorrect: 3595, Skipped: 0, Score: -28490.00
# Test Accuracy: 0.01%
# Epoch 89, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 89, Batch 100, Loss: 0.001, Acc: 99.969%
# Epoch 89, Batch 200, Loss: 0.000, Acc: 99.977%
# Epoch 89, Batch 300, Loss: 0.000, Acc: 99.977%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6358, Incorrect: 3642, Skipped: 0, Score: -28928.00
# Batch 2: Correct: 6412, Incorrect: 3588, Skipped: 0, Score: -26462.00
# Test Accuracy: 0.01%
# Epoch 90, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 90, Batch 100, Loss: 0.000, Acc: 99.969%
# Epoch 90, Batch 200, Loss: 0.000, Acc: 99.969%
# Epoch 90, Batch 300, Loss: 0.000, Acc: 99.966%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6345, Incorrect: 3655, Skipped: 0, Score: -27830.00
# Batch 2: Correct: 6401, Incorrect: 3599, Skipped: 0, Score: -27668.00
# Test Accuracy: 0.01%
# Epoch 91, Batch 0, Loss: 10.003, Acc: 99.219%
# Epoch 91, Batch 100, Loss: 0.099, Acc: 99.985%
# Epoch 91, Batch 200, Loss: 0.050, Acc: 99.977%
# Epoch 91, Batch 300, Loss: 0.033, Acc: 99.982%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6361, Incorrect: 3639, Skipped: 0, Score: -30632.00
# Batch 2: Correct: 6426, Incorrect: 3574, Skipped: 0, Score: -27668.00
# Test Accuracy: 0.01%
# Epoch 92, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 92, Batch 100, Loss: 0.000, Acc: 99.992%
# Epoch 92, Batch 200, Loss: 0.000, Acc: 99.984%
# Epoch 92, Batch 300, Loss: 0.000, Acc: 99.977%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6368, Incorrect: 3632, Skipped: 0, Score: -29354.00
# Batch 2: Correct: 6392, Incorrect: 3608, Skipped: 0, Score: -28088.00
# Test Accuracy: 0.01%
# Epoch 93, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 93, Batch 100, Loss: 0.000, Acc: 99.977%
# Epoch 93, Batch 200, Loss: 0.000, Acc: 99.973%
# Epoch 93, Batch 300, Loss: 0.000, Acc: 99.974%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6373, Incorrect: 3627, Skipped: 0, Score: -29456.00
# Batch 2: Correct: 6411, Incorrect: 3589, Skipped: 0, Score: -27092.00
# Test Accuracy: 0.01%
# Epoch 94, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 94, Batch 100, Loss: 0.000, Acc: 99.969%
# Epoch 94, Batch 200, Loss: 0.000, Acc: 99.973%
# Epoch 94, Batch 300, Loss: 0.000, Acc: 99.979%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6361, Incorrect: 3639, Skipped: 0, Score: -28952.00
# Batch 2: Correct: 6422, Incorrect: 3578, Skipped: 0, Score: -28376.00
# Test Accuracy: 0.01%
# Epoch 95, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 95, Batch 100, Loss: 0.000, Acc: 99.969%
# Epoch 95, Batch 200, Loss: 0.000, Acc: 99.981%
# Epoch 95, Batch 300, Loss: 0.000, Acc: 99.974%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6362, Incorrect: 3638, Skipped: 0, Score: -30452.00
# Batch 2: Correct: 6405, Incorrect: 3595, Skipped: 0, Score: -27656.00
# Test Accuracy: 0.01%
# Epoch 96, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 96, Batch 100, Loss: 0.000, Acc: 99.977%
# Epoch 96, Batch 200, Loss: 0.000, Acc: 99.969%
# Epoch 96, Batch 300, Loss: 0.000, Acc: 99.977%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6357, Incorrect: 3643, Skipped: 0, Score: -30026.00
# Batch 2: Correct: 6411, Incorrect: 3589, Skipped: 0, Score: -28442.00
# Test Accuracy: 0.01%
# Epoch 97, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 97, Batch 100, Loss: 0.000, Acc: 99.969%
# Epoch 97, Batch 200, Loss: 0.000, Acc: 99.965%
# Epoch 97, Batch 300, Loss: 0.000, Acc: 99.966%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6374, Incorrect: 3626, Skipped: 0, Score: -28292.00
# Batch 2: Correct: 6415, Incorrect: 3585, Skipped: 0, Score: -27746.00
# Test Accuracy: 0.01%
# Epoch 98, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 98, Batch 100, Loss: 0.000, Acc: 99.969%
# Epoch 98, Batch 200, Loss: 0.000, Acc: 99.977%
# Epoch 98, Batch 300, Loss: 0.000, Acc: 99.977%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6340, Incorrect: 3660, Skipped: 0, Score: -29708.00
# Batch 2: Correct: 6412, Incorrect: 3588, Skipped: 0, Score: -28460.00
# Test Accuracy: 0.01%
# Epoch 99, Batch 0, Loss: 0.000, Acc: 100.000%
# Epoch 99, Batch 100, Loss: 0.000, Acc: 99.969%
# Epoch 99, Batch 200, Loss: 0.000, Acc: 99.973%
# Epoch 99, Batch 300, Loss: 0.000, Acc: 99.969%
# Predictions saved to submission.csv
#
# Batch 1: Correct: 6362, Incorrect: 3638, Skipped: 0, Score: -27038.00
# Batch 2: Correct: 6401, Incorrect: 3599, Skipped: 0, Score: -28184.00
# Test Accuracy: 0.01%
